# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")
vacation_df.tail(50)
# Out:
#      City_ID               City Country  Max Temp Current Discription  \
# 567      631            Caucaia      BR     80.55    scattered clouds
# 568      632     Ferkessedougou      CI     80.19       broken clouds
# 569      633            Talusan      PH     81.36     overcast clouds
# 570      634               Bida      NG     80.62     overcast clouds
# 571      635             Maketu      NZ     76.60           clear sky
# 572      636      Saint-Georges      GD     79.09     overcast clouds
# 573      637              Pando      UY     68.09           clear sky
# 574      638  Zheleznodorozhnyy      RU     45.14     overcast clouds
# 575      639           San Jose      US     74.88               smoke
# 576      641          Sijunjung      ID     81.82       broken clouds
# 577      642          San Ramon      US     75.42           clear sky
# 578      643             Arauca      CO     82.36     overcast clouds
# 579      645              Orlik      RU     18.48     overcast clouds
# 580      646            Melilla      ES     53.98           clear sky
# 581      647          Namatanai      PG     85.53       broken clouds
# 582      648    Haines Junction      CA     33.75       broken clouds
# 583      649            Sawakin      SD     78.30           clear sky
# 584      650          Champaign      US     44.67           clear sky
# 585      651            Linshui      CN     83.97           clear sky
# 586      652                Kem      RU     31.01       broken clouds
# 587      653            Seguela      CI     72.55       broken clouds
# 588      654         Luzilandia      BR     73.38       moderate rain
# 589      655       Portoferraio      IT     51.58           clear sky
# 590      656             Nayoro      JP     50.09     overcast clouds
# 591      657              Mahon      ES     46.96    scattered clouds
# 592      658      Ust-Ordynskiy      RU     35.29     overcast clouds
# 593      659    Verkhnevilyuysk      RU     25.74     overcast clouds
# 594      660              Lerik      AZ     45.32     overcast clouds
# 595      661             Pauini      BR     73.94     overcast clouds
# 596      662            Vaitape      PF     82.31          light rain
# 597      663             Dalvik      IS     22.93     overcast clouds
# 598      664                Epe      NG     78.06     overcast clouds
# 599      665           Falmouth      GB     40.10       broken clouds
# 600      666           Yarmouth      US     48.25           clear sky
# 601      667             Itoman      JP     77.38       broken clouds
# 602      668               Sola      VU     82.49          few clouds
# 603      670               Sibu      MY     77.31    scattered clouds
# 604      671            Kaduqli      SD     85.75       broken clouds
# 605      672         Safranbolu      TR     52.79     overcast clouds
# 606      673               Axim      GH     80.28     overcast clouds
# 607      674              Pasni      PK     79.52     overcast clouds
# 608      675           Noyabrsk      RU      9.77     overcast clouds
# 609      676            Balabac      PH     79.59          light rain
# 610      677           Smithers      CA     37.72          few clouds
# 611      678           Povenets      RU     32.85                snow
# 612      679            Kendari      ID     83.61     overcast clouds
# 613      681                Ilo      PE     66.56    scattered clouds
# 614      682          Massaguet      TD     87.01     overcast clouds
# 615      684       Port Hedland      AU     89.65           clear sky
# 616      685          Ketchikan      US     42.78       broken clouds
#
#          Lat       Lng                                        Hotel Name
# 567  -3.7361  -38.6531               M.O.S. Logística - Filial Fortaleza
# 568   9.6000   -5.2000                                     Hotel Chateau
# 569   7.4267  122.8103                              Niesas Lodging House
# 570   9.0833    6.0167                                       Royal Suite
# 571 -37.7667  176.4500                         Maketu Beach Holiday Park
# 572  12.0564  -61.7485                     Radisson Grenada Beach Resort
# 573 -34.7167  -55.9500                                  viviendas mvotma
# 574  55.7503   38.0042                                        Hotel Dali
# 575  37.3394 -121.8950                               The Westin San Jose
# 576  -0.6876  100.9537                                Hotel Bukik Gadang
# 577  37.7799 -121.9780                                San Ramon Marriott
# 578   7.0847  -70.7591                                Hotel Verano Plaza
# 579  52.5178   99.8250                      Gostevoy Dom Mini Gostinitsa
# 580  35.2937   -2.9383                                      Hotel Anfora
# 581  -3.6667  152.4333                             Seagulls Inn Namatani
# 582  60.7522 -137.5108                                      Parkside Inn
# 583  19.1059   37.3321                                       فندق الدويم
# 584  40.1334  -88.2001  Comfort Suites Urbana Champaign, University Area
# 585  36.4247  114.2047                          Fengfeng Dianchang Hotel
# 586  64.9555   34.5793                                            Kuzova
# 587   7.9611   -6.6731                                Hotel le Carrefour
# 588  -3.4578  -42.3703                                    Pousada Pontes
# 589  42.8115   10.3146                               Hotel Villa Ombrosa
# 590  44.3506  142.4578                                            名寄 大雪荘
# 591  39.8885    4.2658                                      ARTIEM Capri
# 592  52.8050  104.7508                                   Hotel Metelitsa
# 593  63.4453  120.3167                                   Gostinitsa Mila
# 594  38.7726   48.4128                                          9 QARDAŞ
# 595  -7.7136  -66.9764                                   Casa do Kiwliks
# 596 -16.5167 -151.7500                              Conrad Bora Bora Nui
# 597  65.9702  -18.5286                                  Dalvík HI Hostel
# 598   6.5841    3.9834                                    MAGVILLE HOTEL
# 599  50.1544   -5.0711                                The Falmouth Hotel
# 600  41.7057  -70.2286                                  Blue Rock Resort
# 601  26.1247  127.6694             Southern Beach Hotel & Resort Okinawa
# 602 -13.8833  167.5500                                Leumerus Bungalows
# 603   2.3000  111.8167                                 RH HOTEL (4 Star)
# 604  11.0167   29.7167                                           Nussyba
# 605  41.2508   32.6942                            GuleviSafranbolu Hotel
# 606   4.8699   -2.2405                         Axim Beach Resort And Spa
# 607  25.2631   63.4710                                    Kashmiri Hotal
# 608  63.1994   75.4507                                    Hotel Uyutnaya
# 609   7.9868  117.0645                           Batalla’s Lodging House
# 610  54.7804 -127.1743     Prestige Hudson Bay Lodge, Premier Collection
# 611  62.8487   34.8262                    Eko Otel' Bol'shaya Medveditsa
# 612  -3.9450  122.4989                                       Hotel Wixel
# 613 -17.6394  -71.3375                                 Torreblanca Hotel
# 614  12.4755   15.4365                                          Alwatane
# 615 -20.3167  118.5667                               The Esplanade Hotel
# 616  55.3422 -131.6461                                 Snow's Cove Lodge

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Discription/dt><dd>{Current Discription} and {Max Temp} °F</dd>
</dl>
"""
# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.

max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(47.6,-52.7), zoom_level=3.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.
#vacation_df.head()
vacation_start = vacation_df.loc[vacation_df["City"]=="Merrill"]
vacation_end = vacation_df.loc[vacation_df["City"]=="Merrill"]
vacation_stop1 = vacation_df.loc[vacation_df["City"]=="Saint Anthony"]
vacation_stop2 = vacation_df.loc[vacation_df["City"]=="Spencer"] 
vacation_stop3 = vacation_df.loc[vacation_df["City"]=="Champaign"]

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start["Lat"].to_numpy()[0], vacation_start["Lng"].to_numpy()[0]
end = vacation_end["Lat"].to_numpy()[0], vacation_end["Lng"].to_numpy()[0]
stop1 = vacation_stop1["Lat"].to_numpy()[0], vacation_stop1["Lng"].to_numpy()[0]
stop2 = vacation_stop2["Lat"].to_numpy()[0], vacation_stop2["Lng"].to_numpy()[0]
stop3 = vacation_stop3["Lat"].to_numpy()[0], vacation_stop3["Lng"].to_numpy()[0]

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
import gmaps
import gmaps.datasets
gmaps.configure(api_key=g_key)
# Latitude-longitude pairs
fig = gmaps.figure()
vacation_itinerary = gmaps.directions_layer(
        start, end, waypoints=[stop1, stop2, stop3],
        travel_mode='DRIVING')

fig.add_layer(vacation_itinerary)


fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
frames = [vacation_start,vacation_end,vacation_stop1,vacation_stop2,vacation_stop3]
itinerary_df = pd.concat(frames,ignore_index=True)
itinerary_df
# Out:
#    City_ID           City Country  Max Temp Current Discription      Lat  \
# 0      341       Griffith      US     38.14          light rain  41.5284
# 1      341       Griffith      US     38.14          light rain  41.5284
# 2      160        Le Mars      US     51.57           clear sky  42.7942
# 3      329  Saint Anthony      US     46.65           clear sky  45.0205
# 4      615        Baraboo      US     37.54     overcast clouds  43.4711
#
#        Lng                                         Hotel Name
# 0 -87.4237                          Apartment above Depot Bar
# 1 -87.4237                          Apartment above Depot Bar
# 2 -96.1656  Holiday Inn Express & Suites Le Mars, an IHG H...
# 3 -93.2180  Holiday Inn Express Roseville-St. Paul, an IHG...
# 4 -89.7443                              Thunderbird Motor Inn

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Discription/dt><dd>{Current Discription} and {Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
fig = gmaps.figure()
max_temp = itinerary_df["Max Temp"]


gmaps.figure()

marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)

fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
