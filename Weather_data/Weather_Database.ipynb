# %%
# Import the random module.
import random

# %%
x =1
latitudes =[]
random_lat = random.randint(-90,89)+random.random()
latitudes.append(random_lat)
x+=1

# %%
latitudes
# Out:
# [-37.633385156550474]

# %%
# Import the NumPy module.
import numpy as np
# Import timeit.
import timeit

# %%
# Create a set of random latitude and longitude combinations.
lats =np.random.uniform(low =90.00,high = 90.00,size =2000)
lngs = np.random.uniform(low= 180.00, high =180.00, size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Import the requests library.
import requests

# %%
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x,y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates :
    print(coordinate[0],coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Chicago"

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
city_weather.text
# Out:
# '{"coord":{"lon":-87.65,"lat":41.85},"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02n"}],"base":"stations","main":{"temp":39.92,"feels_like":35.1,"temp_min":36.09,"temp_max":45.64,"pressure":1013,"humidity":67},"visibility":10000,"wind":{"speed":6.91,"deg":100},"clouds":{"all":20},"dt":1649552887,"sys":{"type":2,"id":2005153,"country":"US","sunrise":1649503186,"sunset":1649550246},"timezone":-18000,"id":4887398,"name":"Chicago","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -87.65, 'lat': 41.85},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02n'}],
#  'base': 'stations',
#  'main': {'temp': 39.92,
#   'feels_like': 35.1,
#   'temp_min': 36.09,
#   'temp_max': 45.64,
#   'pressure': 1013,
#   'humidity': 67},
#  'visibility': 10000,
#  'wind': {'speed': 6.91, 'deg': 100},
#  'clouds': {'all': 20},
#  'dt': 1649552887,
#  'sys': {'type': 2,
#   'id': 2005153,
#   'country': 'US',
#   'sunrise': 1649503186,
#   'sunset': 1649550246},
#  'timezone': -18000,
#  'id': 4887398,
#  'name': 'Chicago',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Chicago"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -87.65, 'lat': 41.85},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02n'}],
#  'base': 'stations',
#  'main': {'temp': 39.92,
#   'feels_like': 35.1,
#   'temp_min': 36.09,
#   'temp_max': 45.64,
#   'pressure': 1013,
#   'humidity': 67},
#  'visibility': 10000,
#  'wind': {'speed': 6.91, 'deg': 100},
#  'clouds': {'all': 20},
#  'dt': 1649553009,
#  'sys': {'type': 2,
#   'id': 2005153,
#   'country': 'US',
#   'sunrise': 1649503186,
#   'sunset': 1649550246},
#  'timezone': -18000,
#  'id': 4887398,
#  'name': 'Chicago',
#  'cod': 200}

# %%
# Get the JSON data.
Chicago_data = city_weather.json()

# %%
Chicago_data['sys']
# Out:
# {'type': 2,
#  'id': 2005153,
#  'country': 'US',
#  'sunrise': 1649416885,
#  'sunset': 1649463780}

# %%
Chicago_data['sys']['country']
# Out:
# 'US'

# %%
Chicago_data['dt']
# Out:
# 1649458896

# %%
Chicago_data["weather"][0]["description"]
# Out:
# 'mist'

# %%
#Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 741

# %%
cities
# Out:
# ['auki',
#  'codrington',
#  'nizhneyansk',
#  'beyneu',
#  'hondo',
#  'khatanga',
#  'hermanus',
#  'chokurdakh',
#  'najran',
#  'bathsheba',
#  'rikitea',
#  'cape town',
#  'amderma',
#  'ushuaia',
#  'silver city',
#  'port alfred',
#  'kaifeng',
#  'aksarka',
#  'saskylakh',
#  'ilulissat',
#  'vanimo',
#  'bluff',
#  'oshawa',
#  'bengkulu',
#  'pozo colorado',
#  'lagunas',
#  'esperance',
#  'clonmel',
#  'kimbe',
#  'sept-iles',
#  'hobart',
#  'bredasdorp',
#  'luderitz',
#  'barentsburg',
#  'kudahuvadhoo',
#  'mabaruma',
#  'pochutla',
#  'flinders',
#  'cap malheureux',
#  'busselton',
#  'kodiak',
#  'atuona',
#  'butaritari',
#  'vaini',
#  'qaanaaq',
#  'arlit',
#  'tuatapere',
#  'belushya guba',
#  'barrow',
#  'kosa',
#  'saint-philippe',
#  'bairiki',
#  'pemangkat',
#  'isiro',
#  'tumannyy',
#  'raikot',
#  'hithadhoo',
#  'moron',
#  'kapaa',
#  'hilo',
#  'dujuma',
#  'mataura',
#  'dakar',
#  'lebu',
#  'illoqqortoormiut',
#  'yumen',
#  'tonantins',
#  'vardo',
#  'jamestown',
#  'dali',
#  'georgetown',
#  'mayumba',
#  'kem',
#  'liepaja',
#  'ordynskoye',
#  'hami',
#  'acapulco',
#  'hervey bay',
#  'sao filipe',
#  'provideniya',
#  'cidreira',
#  'pokhara',
#  'lasa',
#  'east london',
#  'arima',
#  'albany',
#  'zhangye',
#  'cumra',
#  'sorkjosen',
#  'tamboril',
#  'necochea',
#  'severo-kurilsk',
#  'alofi',
#  'saleaula',
#  'kokkola',
#  'coahuayana',
#  'dingle',
#  'kavieng',
#  'vaitupu',
#  'comodoro rivadavia',
#  'coquimbo',
#  'shache',
#  'saint anthony',
#  'ketchikan',
#  'reconquista',
#  'taolanaro',
#  'upernavik',
#  'umzimvubu',
#  'sentyabrskiy',
#  'ostrovnoy',
#  'shimoda',
#  'lagoa',
#  'bethel',
#  'dikson',
#  'turayf',
#  'orlik',
#  'novyy urengoy',
#  'sitka',
#  'cabo san lucas',
#  'fowa',
#  'roebourne',
#  'isangel',
#  'richards bay',
#  'pangnirtung',
#  'solton',
#  'samusu',
#  'thompson',
#  'karratha',
#  'bonavista',
#  'blythe',
#  'puerto ayora',
#  'ust-omchug',
#  'nuuk',
#  'tasiilaq',
#  'nikolskoye',
#  'grand river south east',
#  'attawapiskat',
#  'avarua',
#  'nam tha',
#  'arman',
#  'de aar',
#  'ericeira',
#  'haibowan',
#  'arenapolis',
#  'torbay',
#  'tessalit',
#  'saint george',
#  'bumba',
#  'haikou',
#  'puerto colombia',
#  'chamalieres',
#  'samarkand',
#  'namibe',
#  'port macquarie',
#  'ambilobe',
#  'punta arenas',
#  'gulu',
#  'atar',
#  'hare bay',
#  'maniitsoq',
#  'formoso do araguaia',
#  'austin',
#  'kayes',
#  'lakatoro',
#  'west wendover',
#  'lompoc',
#  'klaksvik',
#  'matara',
#  'victoria',
#  'souillac',
#  'beringovskiy',
#  'airai',
#  'dalton',
#  'ribeira grande',
#  'kulhudhuffushi',
#  'oktyabrskoye',
#  'hasaki',
#  'evensk',
#  'rio grande',
#  'muros',
#  'yar-sale',
#  'talnakh',
#  'kwinana',
#  'kruisfontein',
#  'south lake tahoe',
#  'sembe',
#  'jaszdozsa',
#  'kahului',
#  'katsuura',
#  'kaitangata',
#  'bafoulabe',
#  'mys shmidta',
#  'lolua',
#  'marzuq',
#  'kieta',
#  'longyearbyen',
#  'the valley',
#  'peschanokopskoye',
#  'lavrentiya',
#  'port hardy',
#  'pisco',
#  'ponta do sol',
#  'yomitan',
#  'bang bo',
#  'voh',
#  'sabang',
#  'batemans bay',
#  'emba',
#  'tocopilla',
#  'santo antonio de jesus',
#  'naze',
#  'char bhadrasan',
#  'bambous virieux',
#  'coihaique',
#  'adrar',
#  'tomatlan',
#  'helena',
#  'nantucket',
#  'mahebourg',
#  'new norfolk',
#  'chifeng',
#  'vao',
#  'dunedin',
#  'kavaratti',
#  'batu gajah',
#  'atambua',
#  'hope',
#  'nanortalik',
#  'los llanos de aridane',
#  'tabiauea',
#  'malakal',
#  'chapais',
#  'brive-la-gaillarde',
#  'cananea',
#  'ivot',
#  'castro',
#  'pevek',
#  'lesogorsk',
#  'kattivakkam',
#  'avera',
#  'kaeo',
#  'mount gambier',
#  'hihifo',
#  'burgos',
#  'kichmengskiy gorodok',
#  'palmer',
#  'maryborough',
#  'seymchan',
#  'batagay-alyta',
#  'starokozache',
#  'yambio',
#  'sayyan',
#  'grand gaube',
#  'paamiut',
#  'tachi',
#  'mizdah',
#  'strelka',
#  'mareeba',
#  'bahia blanca',
#  'mar del plata',
#  'benghazi',
#  'broken hill',
#  'chuy',
#  'plakhtiyivka',
#  'te anau',
#  'amahai',
#  'tuktoyaktuk',
#  'balimo',
#  'cabedelo',
#  'viedma',
#  'charagua',
#  'boguchany',
#  'faanui',
#  'hammerfest',
#  'hun',
#  'tatvan',
#  'santa maria',
#  'stornoway',
#  'rawson',
#  'nazira',
#  'kamenka',
#  'nadym',
#  'arraial do cabo',
#  'alyangula',
#  'yellowknife',
#  'pasni',
#  'abu kamal',
#  'novouzensk',
#  'aklavik',
#  'khandbari',
#  'pemba',
#  'nokaneng',
#  'kapoeta',
#  'alta floresta',
#  'unye',
#  'thinadhoo',
#  'bilma',
#  'sahrak',
#  'berlevag',
#  'okitipupa',
#  'broome',
#  'orzhytsya',
#  'la crosse',
#  'zyryanka',
#  'yantal',
#  'hamilton',
#  'lorengau',
#  'russell',
#  'pandan',
#  'eureka',
#  'fairbanks',
#  'matagami',
#  'siuna',
#  'ancud',
#  'bras-panon',
#  'qurayyat',
#  'antibes',
#  'arang',
#  'norman wells',
#  'maningrida',
#  'presidencia roque saenz pena',
#  'nanning',
#  'clyde river',
#  'rosarito',
#  'pathein',
#  'bermeo',
#  'charters towers',
#  'grindavik',
#  'champerico',
#  'port elizabeth',
#  'byron bay',
#  'ambulu',
#  'aykhal',
#  'chontalpa',
#  'rawannawi',
#  'murgab',
#  'eirunepe',
#  'letlhakane',
#  'batagay',
#  'meyungs',
#  'luohe',
#  'kedgwick',
#  'takaka',
#  'denpasar',
#  'huarmey',
#  'ingham',
#  'alibag',
#  'alto longa',
#  'san juan del cesar',
#  'leningradskiy',
#  'mineiros',
#  'timra',
#  'anloga',
#  'issia',
#  'jinchang',
#  'vestmannaeyjar',
#  'umm durman',
#  'gazni',
#  'saint-pierre',
#  'garh maharaja',
#  'sao desiderio',
#  'saldanha',
#  'along',
#  'swan river',
#  'tecoanapa',
#  'bukan',
#  'karatuzskoye',
#  'udaipura',
#  'sao felix do xingu',
#  'ngukurr',
#  'martil',
#  'exaplatanos',
#  'egvekinot',
#  'ahuimanu',
#  'north platte',
#  'leshukonskoye',
#  'sokolo',
#  'halalo',
#  'caravelas',
#  'vestmanna',
#  'alice springs',
#  'salinopolis',
#  'sandakan',
#  'marcona',
#  'mbulu',
#  'touros',
#  'mayo',
#  'san patricio',
#  'ondjiva',
#  'vila franca do campo',
#  'quatre cocos',
#  'kathu',
#  'asyut',
#  'ardabil',
#  'portland',
#  'guerrero negro',
#  'carnarvon',
#  'bandarbeyla',
#  'tsihombe',
#  'tabuk',
#  'chara',
#  'gondanglegi',
#  'wabrzezno',
#  'namtsy',
#  'gizo',
#  'la tuque',
#  'arras',
#  'husavik',
#  'san bartolome de tirajana',
#  'constitucion',
#  'chernyshevskiy',
#  'monrovia',
#  'elko',
#  'nhamunda',
#  'la ronge',
#  'nizwa',
#  'djougou',
#  'tabas',
#  'nikolayevka',
#  'sisimiut',
#  'lazaro cardenas',
#  'dovers',
#  'cahir',
#  'north branch',
#  'saint-joseph',
#  'khaniotis',
#  'natal',
#  'acarau',
#  'lianran',
#  'malatya',
#  'kota bahru',
#  'ribeira brava',
#  'porto novo',
#  'linqu',
#  'kloulklubed',
#  'erenhot',
#  'ilhabela',
#  'fort nelson',
#  'lafiagi',
#  'nishihara',
#  'wasilla',
#  'la montanita',
#  'satitoa',
#  'pilao arcado',
#  'olafsvik',
#  'ballina',
#  'machakos',
#  'magadi',
#  'tilichiki',
#  'havoysund',
#  'kautokeino',
#  'ariquemes',
#  'buenaventura',
#  'marsh harbour',
#  'jeremie',
#  'teahupoo',
#  'mana',
#  'rancho palos verdes',
#  'belyy yar',
#  'giddalur',
#  'yabrud',
#  'yingcheng',
#  'vilhena',
#  'talcahuano',
#  'providencia',
#  'businga',
#  'chagda',
#  'kibre mengist',
#  'boa vista',
#  'davila',
#  'padang',
#  'hualmay',
#  'humaita',
#  'makung',
#  'ramon',
#  'orikum',
#  'namatanai',
#  'kalaleh',
#  'ilebo',
#  'usinsk',
#  'sola',
#  'wawa',
#  'henties bay',
#  'ouegoa',
#  'touba',
#  'tarudant',
#  'san felipe',
#  'lalomanu',
#  'sioux lookout',
#  'srednekolymsk',
#  'rungata',
#  'talara',
#  'nome',
#  'chambas',
#  'port said',
#  'mitsamiouli',
#  'buraydah',
#  'louga',
#  'stromness',
#  'umm jarr',
#  'pointe michel',
#  'marquette',
#  'chernoyerkovskaya',
#  'noumea',
#  'bayir',
#  'fortuna',
#  'olinda',
#  'svetlogorsk',
#  'mergui',
#  'bilibino',
#  'herat',
#  'dole',
#  'deputatskiy',
#  'chabahar',
#  'stonewall',
#  'gorlice',
#  'fayaoue',
#  'olavarria',
#  'kuche',
#  'ambunti',
#  'yunhe',
#  'lamphun',
#  'panaba',
#  'jarjis',
#  'paradwip',
#  'yinchuan',
#  'togur',
#  'ceuta',
#  'buqayq',
#  'geraldton',
#  'preobrazheniye',
#  'hofn',
#  'longonjo',
#  'zholymbet',
#  'qaqortoq',
#  'bastia',
#  'basco',
#  'awjilah',
#  'sosnovo-ozerskoye',
#  'taiyuan',
#  'birobidzhan',
#  'aflu',
#  'camacha',
#  'iskateley',
#  'palizada',
#  'abonnema',
#  'hobyo',
#  'parksepa',
#  'wazzan',
#  'uvarovka',
#  'balabac',
#  'oksfjord',
#  'cordoba',
#  'ahipara',
#  'casper',
#  'mercedes',
#  'gorontalo',
#  'ixtapa',
#  'sistranda',
#  'nsanje',
#  'rio gallegos',
#  'vostok',
#  'ust-karsk',
#  'san cristobal',
#  'saint-tite',
#  'polyarnyye zori',
#  'monteprandone',
#  'kiruna',
#  'birjand',
#  'puerto escondido',
#  'brae',
#  'mangit',
#  'tazovskiy',
#  'phan thiet',
#  'chemainus',
#  'horizontina',
#  'cody',
#  'bowen',
#  'ende',
#  'belmonte',
#  'hay river',
#  'phek',
#  'ambodifototra',
#  'stokmarknes',
#  'poum',
#  'pula',
#  'karaul',
#  'phuket',
#  'tha muang',
#  'novovarshavka',
#  'dinard',
#  'port keats',
#  'fukue',
#  'roura',
#  'sao francisco',
#  'bonwapitse',
#  'gobabis',
#  'puerto ayacucho',
#  'koulikoro',
#  'gambela',
#  'san quintin',
#  'wadi musa',
#  'sibolga',
#  'of',
#  'nelson bay',
#  'vigrestad',
#  'falaleu',
#  'tiksi',
#  'itarema',
#  'irbeyskoye',
#  'tambopata',
#  'palmas',
#  'kenai',
#  'zhitikara',
#  'ola',
#  'suez',
#  'la cruz',
#  'truth or consequences',
#  'yartsevo',
#  'narsaq',
#  'xam nua',
#  'bud',
#  'jalu',
#  'port lincoln',
#  'vila velha',
#  'madawaska',
#  'fallon',
#  'cervo',
#  'sawakin',
#  'kuytun',
#  'yemelyanovo',
#  'svetlyy',
#  'tawkar',
#  'khani',
#  'ca mau',
#  'taksimo',
#  'antalaha',
#  'nalut',
#  'sao joao da barra',
#  'neyshabur',
#  'iqaluit',
#  'boende',
#  'ambanja',
#  'cherskiy',
#  'tubruq',
#  'miri',
#  'caucaia',
#  'tshane',
#  'ewa beach',
#  'kapit',
#  'gasa',
#  'lanxi',
#  'qasigiannguit',
#  'solnechnyy',
#  'nandi',
#  'el dorado',
#  'bekasi',
#  'laguna',
#  'nishiwaki',
#  'midland',
#  'calbuco',
#  'ogulin',
#  'santa isabel',
#  'goderich',
#  'kupang',
#  'vysokogornyy',
#  'amga',
#  'karpathos',
#  'tabou',
#  'el tigre',
#  'bemidji',
#  'tsalka',
#  'college',
#  'klyuchi',
#  'imbituba',
#  'litayen',
#  'buguruslan',
#  'maxixe',
#  'makat',
#  'flin flon',
#  'okha',
#  'karla',
#  'barbar',
#  'mildura',
#  'gonbad-e qabus',
#  'faya',
#  'santa maria del oro',
#  'mahuva',
#  'margate',
#  'potenza',
#  'peniche',
#  'ayia galini',
#  'sorvag',
#  'dwarka',
#  'zalari',
#  'iquique',
#  'mae ramat',
#  'gewane',
#  'antsohihy',
#  'gat',
#  'ust-kuyga',
#  'portel',
#  'port hedland',
#  'areosa',
#  'celestun',
#  'high level',
#  'mackay',
#  'rozivka',
#  'honningsvag']

# %%
import time
from datetime import datetime
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning of the logging ")
print("-------------------------")
# Create counters.
record_count =1
set_count = 1
# Out:
# Beginning of the logging
# -------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    #print(city_url)
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
                # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_discription = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Discription": city_current_discription})
                          

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | thompson
# Processing Record 3 of Set 1 | norman wells
# Processing Record 4 of Set 1 | shetpe
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | guanica
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | port alfred
# Processing Record 10 of Set 1 | banyo
# Processing Record 11 of Set 1 | pilar
# Processing Record 12 of Set 1 | yellowknife
# Processing Record 13 of Set 1 | dikson
# Processing Record 14 of Set 1 | acapulco
# Processing Record 15 of Set 1 | kapaa
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | morant bay
# Processing Record 18 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | rezekne
# Processing Record 21 of Set 1 | hobart
# Processing Record 22 of Set 1 | swellendam
# Processing Record 23 of Set 1 | la ronge
# Processing Record 24 of Set 1 | minuri
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 1 | beringovskiy
# Processing Record 28 of Set 1 | fortuna
# Processing Record 29 of Set 1 | afsin
# Processing Record 30 of Set 1 | hasaki
# Processing Record 31 of Set 1 | sinegorye
# Processing Record 32 of Set 1 | coihaique
# Processing Record 33 of Set 1 | ostrovnoy
# Processing Record 34 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 1 | kavaratti
# Processing Record 36 of Set 1 | carutapera
# Processing Record 37 of Set 1 | pacific grove
# Processing Record 38 of Set 1 | avarua
# Processing Record 39 of Set 1 | belaya gora
# Processing Record 40 of Set 1 | rawson
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 1 | chokurdakh
# Processing Record 44 of Set 1 | moose factory
# Processing Record 45 of Set 1 | hithadhoo
# Processing Record 46 of Set 1 | meulaboh
# Processing Record 47 of Set 1 | mabaruma
# Processing Record 48 of Set 1 | yulara
# Processing Record 49 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 1 | kurkino
# Processing Record 1 of Set 2 | baykit
# Processing Record 2 of Set 2 | hella
# Processing Record 3 of Set 2 | tunxi
# City not found. Skipping...
# Processing Record 4 of Set 2 | arraial do cabo
# Processing Record 5 of Set 2 | atuona
# Processing Record 6 of Set 2 | cape town
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 2 | acarau
# Processing Record 10 of Set 2 | narsaq
# Processing Record 11 of Set 2 | boundiali
# Processing Record 12 of Set 2 | sakakah
# Processing Record 13 of Set 2 | lebu
# Processing Record 14 of Set 2 | fort saint john
# City not found. Skipping...
# Processing Record 15 of Set 2 | mahuva
# Processing Record 16 of Set 2 | omboue
# Processing Record 17 of Set 2 | upernavik
# Processing Record 18 of Set 2 | atar
# Processing Record 19 of Set 2 | mar del plata
# Processing Record 20 of Set 2 | soyo
# Processing Record 21 of Set 2 | sao joao da barra
# Processing Record 22 of Set 2 | puro
# Processing Record 23 of Set 2 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 24 of Set 2 | nikolskoye
# Processing Record 25 of Set 2 | talnakh
# Processing Record 26 of Set 2 | saint-philippe
# Processing Record 27 of Set 2 | hoi an
# Processing Record 28 of Set 2 | guerrero negro
# Processing Record 29 of Set 2 | okhotsk
# Processing Record 30 of Set 2 | beloha
# Processing Record 31 of Set 2 | ternate
# Processing Record 32 of Set 2 | poum
# Processing Record 33 of Set 2 | barrow
# Processing Record 34 of Set 2 | ji-parana
# City not found. Skipping...
# Processing Record 35 of Set 2 | kununurra
# Processing Record 36 of Set 2 | airai
# Processing Record 37 of Set 2 | bandarbeyla
# Processing Record 38 of Set 2 | raudeberg
# Processing Record 39 of Set 2 | izhma
# Processing Record 40 of Set 2 | tasiilaq
# Processing Record 41 of Set 2 | georgetown
# Processing Record 42 of Set 2 | ribeira grande
# Processing Record 43 of Set 2 | carnarvon
# Processing Record 44 of Set 2 | bacolod
# Processing Record 45 of Set 2 | constitucion
# Processing Record 46 of Set 2 | pell city
# Processing Record 47 of Set 2 | port augusta
# Processing Record 48 of Set 2 | husavik
# Processing Record 49 of Set 2 | mata
# Processing Record 50 of Set 2 | hermanus
# Processing Record 1 of Set 3 | veraval
# Processing Record 2 of Set 3 | dingle
# Processing Record 3 of Set 3 | thunder bay
# Processing Record 4 of Set 3 | bolobo
# Processing Record 5 of Set 3 | hornepayne
# Processing Record 6 of Set 3 | bilibino
# Processing Record 7 of Set 3 | kamaishi
# Processing Record 8 of Set 3 | yar-sale
# Processing Record 9 of Set 3 | takapau
# Processing Record 10 of Set 3 | riyadh
# Processing Record 11 of Set 3 | san felipe
# Processing Record 12 of Set 3 | vila franca do campo
# Processing Record 13 of Set 3 | umm lajj
# Processing Record 14 of Set 3 | wah
# Processing Record 15 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 3 | boa esperanca
# Processing Record 17 of Set 3 | knysna
# Processing Record 18 of Set 3 | aguimes
# Processing Record 19 of Set 3 | port lincoln
# Processing Record 20 of Set 3 | constantine
# Processing Record 21 of Set 3 | touros
# Processing Record 22 of Set 3 | coari
# Processing Record 23 of Set 3 | sinnamary
# Processing Record 24 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 25 of Set 3 | vardo
# Processing Record 26 of Set 3 | maceio
# Processing Record 27 of Set 3 | jamestown
# Processing Record 28 of Set 3 | severo-kurilsk
# Processing Record 29 of Set 3 | ust-nera
# Processing Record 30 of Set 3 | matagami
# Processing Record 31 of Set 3 | souillac
# Processing Record 32 of Set 3 | bonavista
# Processing Record 33 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 34 of Set 3 | kholm
# Processing Record 35 of Set 3 | marawi
# Processing Record 36 of Set 3 | toyooka
# Processing Record 37 of Set 3 | deputatskiy
# Processing Record 38 of Set 3 | mao
# Processing Record 39 of Set 3 | faanui
# Processing Record 40 of Set 3 | cabo san lucas
# Processing Record 41 of Set 3 | broome
# Processing Record 42 of Set 3 | redlands
# Processing Record 43 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 3 | porto novo
# Processing Record 45 of Set 3 | mwinilunga
# Processing Record 46 of Set 3 | diego de almagro
# Processing Record 47 of Set 3 | vila velha
# Processing Record 48 of Set 3 | cockburn town
# Processing Record 49 of Set 3 | ridgecrest
# Processing Record 50 of Set 3 | hildburghausen
# Processing Record 1 of Set 4 | paita
# Processing Record 2 of Set 4 | tuktoyaktuk
# Processing Record 3 of Set 4 | kodiak
# Processing Record 4 of Set 4 | ifakara
# Processing Record 5 of Set 4 | khatanga
# Processing Record 6 of Set 4 | san patricio
# Processing Record 7 of Set 4 | qaanaaq
# Processing Record 8 of Set 4 | lubango
# Processing Record 9 of Set 4 | bambous virieux
# Processing Record 10 of Set 4 | nador
# Processing Record 11 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 4 | lorengau
# Processing Record 13 of Set 4 | kousseri
# Processing Record 14 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 4 | svetogorsk
# Processing Record 16 of Set 4 | tommot
# Processing Record 17 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 4 | mosquera
# Processing Record 19 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 4 | washington
# Processing Record 21 of Set 4 | kruisfontein
# Processing Record 22 of Set 4 | nanortalik
# Processing Record 23 of Set 4 | tucurui
# Processing Record 24 of Set 4 | taoudenni
# Processing Record 25 of Set 4 | port elizabeth
# Processing Record 26 of Set 4 | wajima
# Processing Record 27 of Set 4 | tilichiki
# Processing Record 28 of Set 4 | castro
# Processing Record 29 of Set 4 | kantunilkin
# Processing Record 30 of Set 4 | tambopata
# Processing Record 31 of Set 4 | impfondo
# Processing Record 32 of Set 4 | visby
# Processing Record 33 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 4 | ahipara
# Processing Record 35 of Set 4 | buchanan
# Processing Record 36 of Set 4 | tiksi
# Processing Record 37 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 4 | broken hill
# Processing Record 39 of Set 4 | ambon
# Processing Record 40 of Set 4 | bredasdorp
# Processing Record 41 of Set 4 | cuauhtemoc
# Processing Record 42 of Set 4 | mount gambier
# Processing Record 43 of Set 4 | bulgan
# Processing Record 44 of Set 4 | buguruslan
# Processing Record 45 of Set 4 | bontang
# Processing Record 46 of Set 4 | ereymentau
# Processing Record 47 of Set 4 | tabou
# Processing Record 48 of Set 4 | ivdel
# Processing Record 49 of Set 4 | ambilobe
# Processing Record 50 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 5 | kalmar
# Processing Record 2 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 3 of Set 5 | geraldton
# Processing Record 4 of Set 5 | pisco
# Processing Record 5 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 6 of Set 5 | margate
# Processing Record 7 of Set 5 | kachug
# Processing Record 8 of Set 5 | victoria
# Processing Record 9 of Set 5 | kaitangata
# Processing Record 10 of Set 5 | bang saphan
# Processing Record 11 of Set 5 | tongren
# Processing Record 12 of Set 5 | ponta do sol
# Processing Record 13 of Set 5 | paamiut
# Processing Record 14 of Set 5 | nouadhibou
# Processing Record 15 of Set 5 | fort nelson
# Processing Record 16 of Set 5 | tutoia
# Processing Record 17 of Set 5 | harer
# Processing Record 18 of Set 5 | joura
# Processing Record 19 of Set 5 | padang
# Processing Record 20 of Set 5 | faya
# Processing Record 21 of Set 5 | mahebourg
# Processing Record 22 of Set 5 | iqaluit
# Processing Record 23 of Set 5 | coquimbo
# Processing Record 24 of Set 5 | namibe
# Processing Record 25 of Set 5 | new norfolk
# Processing Record 26 of Set 5 | grand gaube
# Processing Record 27 of Set 5 | isangel
# Processing Record 28 of Set 5 | letlhakane
# Processing Record 29 of Set 5 | longyearbyen
# Processing Record 30 of Set 5 | puerto ayora
# Processing Record 31 of Set 5 | sorland
# Processing Record 32 of Set 5 | praia da vitoria
# Processing Record 33 of Set 5 | oussouye
# Processing Record 34 of Set 5 | kaarina
# Processing Record 35 of Set 5 | morgantown
# Processing Record 36 of Set 5 | provideniya
# Processing Record 37 of Set 5 | hobyo
# Processing Record 38 of Set 5 | kavieng
# Processing Record 39 of Set 5 | hilo
# Processing Record 40 of Set 5 | alofi
# Processing Record 41 of Set 5 | east london
# Processing Record 42 of Set 5 | belmonte
# Processing Record 43 of Set 5 | havelock
# Processing Record 44 of Set 5 | dicabisagan
# Processing Record 45 of Set 5 | lively
# Processing Record 46 of Set 5 | tall kayf
# Processing Record 47 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 48 of Set 5 | tamale
# Processing Record 49 of Set 5 | stromness
# Processing Record 50 of Set 5 | dubrovnik
# Processing Record 1 of Set 6 | talaya
# Processing Record 2 of Set 6 | torbay
# Processing Record 3 of Set 6 | dzaoudzi
# Processing Record 4 of Set 6 | zhicheng
# Processing Record 5 of Set 6 | siirt
# Processing Record 6 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 7 of Set 6 | kutahya
# Processing Record 8 of Set 6 | opuwo
# Processing Record 9 of Set 6 | mecca
# Processing Record 10 of Set 6 | tautira
# Processing Record 11 of Set 6 | saint anthony
# Processing Record 12 of Set 6 | hutchinson
# Processing Record 13 of Set 6 | klaksvik
# Processing Record 14 of Set 6 | saint-francois
# Processing Record 15 of Set 6 | prachuap khiri khan
# Processing Record 16 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 6 | gat
# Processing Record 18 of Set 6 | pevek
# Processing Record 19 of Set 6 | sharanga
# Processing Record 20 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 21 of Set 6 | mehamn
# Processing Record 22 of Set 6 | mtwara
# Processing Record 23 of Set 6 | hvide sande
# Processing Record 24 of Set 6 | selma
# Processing Record 25 of Set 6 | thinadhoo
# Processing Record 26 of Set 6 | malindi
# Processing Record 27 of Set 6 | tashara
# Processing Record 28 of Set 6 | caravelas
# Processing Record 29 of Set 6 | vao
# Processing Record 30 of Set 6 | lagoa
# Processing Record 31 of Set 6 | antalaha
# Processing Record 32 of Set 6 | porto santo
# Processing Record 33 of Set 6 | taft
# Processing Record 34 of Set 6 | bartlesville
# Processing Record 35 of Set 6 | cadillac
# Processing Record 36 of Set 6 | chandil
# Processing Record 37 of Set 6 | chardara
# Processing Record 38 of Set 6 | vydrino
# Processing Record 39 of Set 6 | kampot
# Processing Record 40 of Set 6 | arumbavur
# Processing Record 41 of Set 6 | mizdah
# Processing Record 42 of Set 6 | tateyama
# Processing Record 43 of Set 6 | dobson
# Processing Record 44 of Set 6 | ust-tsilma
# Processing Record 45 of Set 6 | portland
# Processing Record 46 of Set 6 | male
# Processing Record 47 of Set 6 | la maddalena
# Processing Record 48 of Set 6 | nouakchott
# Processing Record 49 of Set 6 | saskylakh
# Processing Record 50 of Set 6 | sedelnikovo
# City not found. Skipping...
# Processing Record 1 of Set 7 | cabinda
# Processing Record 2 of Set 7 | aberdeen
# Processing Record 3 of Set 7 | igra
# Processing Record 4 of Set 7 | saint-pierre
# Processing Record 5 of Set 7 | itupiranga
# Processing Record 6 of Set 7 | bethel
# Processing Record 7 of Set 7 | zeya
# Processing Record 8 of Set 7 | dunedin
# Processing Record 9 of Set 7 | buala
# Processing Record 10 of Set 7 | warkworth
# Processing Record 11 of Set 7 | brae
# Processing Record 12 of Set 7 | mandurah
# Processing Record 13 of Set 7 | saint george
# Processing Record 14 of Set 7 | bafilo
# Processing Record 15 of Set 7 | zephyrhills
# Processing Record 16 of Set 7 | rio branco
# Processing Record 17 of Set 7 | kachiry
# Processing Record 18 of Set 7 | williams lake
# Processing Record 19 of Set 7 | havoysund
# Processing Record 20 of Set 7 | san angelo
# Processing Record 21 of Set 7 | luderitz
# Processing Record 22 of Set 7 | la paz
# Processing Record 23 of Set 7 | miguel hidalgo
# Processing Record 24 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 7 | kosh-agach
# Processing Record 26 of Set 7 | banmo
# City not found. Skipping...
# Processing Record 27 of Set 7 | yarada
# Processing Record 28 of Set 7 | mayo
# Processing Record 29 of Set 7 | libreville
# Processing Record 30 of Set 7 | vestmanna
# Processing Record 31 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 32 of Set 7 | urumqi
# Processing Record 33 of Set 7 | lasa
# Processing Record 34 of Set 7 | qasigiannguit
# Processing Record 35 of Set 7 | kaeo
# Processing Record 36 of Set 7 | najran
# Processing Record 37 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 7 | koppies
# Processing Record 39 of Set 7 | carballo
# Processing Record 40 of Set 7 | morococha
# Processing Record 41 of Set 7 | vad
# Processing Record 42 of Set 7 | namwala
# Processing Record 43 of Set 7 | alekseyevskoye
# Processing Record 44 of Set 7 | ondal
# City not found. Skipping...
# Processing Record 45 of Set 7 | mogadishu
# Processing Record 46 of Set 7 | sovetskiy
# Processing Record 47 of Set 7 | westport
# Processing Record 48 of Set 7 | ferrol
# Processing Record 49 of Set 7 | esperance
# Processing Record 50 of Set 7 | presidencia roque saenz pena
# Processing Record 1 of Set 8 | hofn
# Processing Record 2 of Set 8 | inuvik
# Processing Record 3 of Set 8 | hohhot
# Processing Record 4 of Set 8 | korla
# Processing Record 5 of Set 8 | seydi
# Processing Record 6 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 7 of Set 8 | maloshuyka
# City not found. Skipping...
# Processing Record 8 of Set 8 | harper
# Processing Record 9 of Set 8 | chuy
# Processing Record 10 of Set 8 | salym
# Processing Record 11 of Set 8 | mangochi
# Processing Record 12 of Set 8 | chapais
# Processing Record 13 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 8 | sambava
# Processing Record 15 of Set 8 | brunswick
# Processing Record 16 of Set 8 | ilulissat
# Processing Record 17 of Set 8 | vostok
# Processing Record 18 of Set 8 | svetlogorsk
# Processing Record 19 of Set 8 | paducah
# Processing Record 20 of Set 8 | pemangkat
# Processing Record 21 of Set 8 | ulaangom
# Processing Record 22 of Set 8 | miedzyrzec podlaski
# Processing Record 23 of Set 8 | sandwick
# Processing Record 24 of Set 8 | sao felix do xingu
# Processing Record 25 of Set 8 | lompoc
# Processing Record 26 of Set 8 | bereda
# Processing Record 27 of Set 8 | tarquinia
# Processing Record 28 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 29 of Set 8 | marzuq
# Processing Record 30 of Set 8 | karlovac
# Processing Record 31 of Set 8 | port blair
# Processing Record 32 of Set 8 | bridlington
# Processing Record 33 of Set 8 | khuzhir
# Processing Record 34 of Set 8 | pangai
# Processing Record 35 of Set 8 | champerico
# Processing Record 36 of Set 8 | luena
# Processing Record 37 of Set 8 | tiznit
# Processing Record 38 of Set 8 | yanam
# Processing Record 39 of Set 8 | tshikapa
# Processing Record 40 of Set 8 | kushima
# Processing Record 41 of Set 8 | saldanha
# Processing Record 42 of Set 8 | abha
# Processing Record 43 of Set 8 | umm bab
# Processing Record 44 of Set 8 | college
# Processing Record 45 of Set 8 | aklavik
# Processing Record 46 of Set 8 | camacha
# Processing Record 47 of Set 8 | road town
# Processing Record 48 of Set 8 | yerofey pavlovich
# Processing Record 49 of Set 8 | buraydah
# Processing Record 50 of Set 8 | sault sainte marie
# Processing Record 1 of Set 9 | maragogi
# Processing Record 2 of Set 9 | mizpe ramon
# City not found. Skipping...
# Processing Record 3 of Set 9 | xining
# Processing Record 4 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 5 of Set 9 | rundu
# Processing Record 6 of Set 9 | daoukro
# Processing Record 7 of Set 9 | bengkulu
# Processing Record 8 of Set 9 | obihiro
# Processing Record 9 of Set 9 | myitkyina
# Processing Record 10 of Set 9 | palivere
# Processing Record 11 of Set 9 | killorglin
# Processing Record 12 of Set 9 | codrington
# Processing Record 13 of Set 9 | belyy yar
# Processing Record 14 of Set 9 | bambanglipuro
# Processing Record 15 of Set 9 | vinkovci
# Processing Record 16 of Set 9 | jizan
# Processing Record 17 of Set 9 | priladozhskiy
# Processing Record 18 of Set 9 | tuatapere
# Processing Record 19 of Set 9 | volchikha
# Processing Record 20 of Set 9 | darhan
# Processing Record 21 of Set 9 | consett
# Processing Record 22 of Set 9 | idaho falls
# Processing Record 23 of Set 9 | anadyr
# Processing Record 24 of Set 9 | antofagasta
# Processing Record 25 of Set 9 | andra
# Processing Record 26 of Set 9 | santa isabel
# Processing Record 27 of Set 9 | zhanatas
# City not found. Skipping...
# Processing Record 28 of Set 9 | srednekolymsk
# Processing Record 29 of Set 9 | hollins
# Processing Record 30 of Set 9 | severomuysk
# Processing Record 31 of Set 9 | jibuti
# Processing Record 32 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 33 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 34 of Set 9 | sibolga
# Processing Record 35 of Set 9 | patterson
# Processing Record 36 of Set 9 | cidreira
# Processing Record 37 of Set 9 | duminichi
# Processing Record 38 of Set 9 | strezhevoy
# Processing Record 39 of Set 9 | nemuro
# Processing Record 40 of Set 9 | zhanakorgan
# Processing Record 41 of Set 9 | la tuque
# Processing Record 42 of Set 9 | salihli
# Processing Record 43 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 44 of Set 9 | benxi
# Processing Record 45 of Set 9 | kolokani
# Processing Record 46 of Set 9 | upington
# Processing Record 47 of Set 9 | makat
# Processing Record 48 of Set 9 | carbondale
# Processing Record 49 of Set 9 | olafsvik
# Processing Record 50 of Set 9 | maunabo
# Processing Record 1 of Set 10 | turukhansk
# Processing Record 2 of Set 10 | svobodnyy
# Processing Record 3 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 10 | tohana
# Processing Record 5 of Set 10 | simbahan
# Processing Record 6 of Set 10 | siocon
# Processing Record 7 of Set 10 | katsuura
# Processing Record 8 of Set 10 | prince rupert
# Processing Record 9 of Set 10 | pinehurst
# Processing Record 10 of Set 10 | cuamba
# Processing Record 11 of Set 10 | porteirinha
# Processing Record 12 of Set 10 | bangangte
# Processing Record 13 of Set 10 | zabol
# Processing Record 14 of Set 10 | angra
# City not found. Skipping...
# Processing Record 15 of Set 10 | clyde river
# Processing Record 16 of Set 10 | los llanos de aridane
# Processing Record 17 of Set 10 | huarmey
# Processing Record 18 of Set 10 | sioux lookout
# Processing Record 19 of Set 10 | walvis bay
# Processing Record 20 of Set 10 | bubaque
# Processing Record 21 of Set 10 | sabang
# Processing Record 22 of Set 10 | merrill
# Processing Record 23 of Set 10 | boromo
# Processing Record 24 of Set 10 | sajanan
# Processing Record 25 of Set 10 | uni
# Processing Record 26 of Set 10 | tazovskiy
# Processing Record 27 of Set 10 | versalles
# Processing Record 28 of Set 10 | maniitsoq
# Processing Record 29 of Set 10 | awjilah
# Processing Record 30 of Set 10 | dhidhdhoo
# Processing Record 31 of Set 10 | vryheid
# Processing Record 32 of Set 10 | fukue
# Processing Record 33 of Set 10 | san rafael
# Processing Record 34 of Set 10 | abbeyfeale
# Processing Record 35 of Set 10 | cayenne
# Processing Record 36 of Set 10 | bo rai
# Processing Record 37 of Set 10 | hazorasp
# Processing Record 38 of Set 10 | yakeshi
# Processing Record 39 of Set 10 | zhob
# Processing Record 40 of Set 10 | nhulunbuy
# Processing Record 41 of Set 10 | scottsburgh
# City not found. Skipping...
# Processing Record 42 of Set 10 | sungaipenuh
# Processing Record 43 of Set 10 | skjervoy
# Processing Record 44 of Set 10 | aripuana
# Processing Record 45 of Set 10 | hokitika
# Processing Record 46 of Set 10 | bathsheba
# Processing Record 47 of Set 10 | necochea
# Processing Record 48 of Set 10 | labuhan
# Processing Record 49 of Set 10 | shirgaon
# Processing Record 50 of Set 10 | ishigaki
# Processing Record 1 of Set 11 | rio gallegos
# Processing Record 2 of Set 11 | pathanamthitta
# Processing Record 3 of Set 11 | fuerte olimpo
# Processing Record 4 of Set 11 | berezovyy
# Processing Record 5 of Set 11 | quelimane
# Processing Record 6 of Set 11 | tiarei
# Processing Record 7 of Set 11 | palmer
# Processing Record 8 of Set 11 | pandan
# Processing Record 9 of Set 11 | naze
# Processing Record 10 of Set 11 | araouane
# Processing Record 11 of Set 11 | henties bay
# Processing Record 12 of Set 11 | vaxjo
# Processing Record 13 of Set 11 | nuuk
# Processing Record 14 of Set 11 | mopti
# Processing Record 15 of Set 11 | dubai
# Processing Record 16 of Set 11 | gniezno
# Processing Record 17 of Set 11 | oum hadjer
# Processing Record 18 of Set 11 | lerwick
# Processing Record 19 of Set 11 | sao filipe
# Processing Record 20 of Set 11 | bambui
# Processing Record 21 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 11 | sapernoye
# Processing Record 23 of Set 11 | orcopampa
# Processing Record 24 of Set 11 | novobirilyussy
# Processing Record 25 of Set 11 | hambantota
# Processing Record 26 of Set 11 | zhanaozen
# Processing Record 27 of Set 11 | san carlos de bariloche
# Processing Record 28 of Set 11 | prieska
# Processing Record 29 of Set 11 | phan thiet
# Processing Record 30 of Set 11 | laguna
# Processing Record 31 of Set 11 | dauriya
# Processing Record 32 of Set 11 | teahupoo
# Processing Record 33 of Set 11 | ulaanbaatar
# Processing Record 34 of Set 11 | kenitra
# Processing Record 35 of Set 11 | ancud
# Processing Record 36 of Set 11 | xocali
# Processing Record 37 of Set 11 | spencer
# Processing Record 38 of Set 11 | kamina
# Processing Record 39 of Set 11 | high level
# Processing Record 40 of Set 11 | cururupu
# Processing Record 41 of Set 11 | te anau
# Processing Record 42 of Set 11 | adeje
# Processing Record 43 of Set 11 | kensington
# Processing Record 44 of Set 11 | south venice
# Processing Record 45 of Set 11 | aksarka
# Processing Record 46 of Set 11 | komsomolskiy
# Processing Record 47 of Set 11 | jiangyou
# Processing Record 48 of Set 11 | finschhafen
# Processing Record 49 of Set 11 | albanel
# Processing Record 50 of Set 11 | dillingen
# Processing Record 1 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 2 of Set 12 | rapid valley
# Processing Record 3 of Set 12 | lanxi
# Processing Record 4 of Set 12 | le port
# Processing Record 5 of Set 12 | saarbrucken
# Processing Record 6 of Set 12 | voi
# Processing Record 7 of Set 12 | kulhudhuffushi
# Processing Record 8 of Set 12 | lhokseumawe
# Processing Record 9 of Set 12 | hlobyne
# Processing Record 10 of Set 12 | port-cartier
# Processing Record 11 of Set 12 | kupang
# Processing Record 12 of Set 12 | beidao
# Processing Record 13 of Set 12 | ukiah
# Processing Record 14 of Set 12 | mount pleasant
# Processing Record 15 of Set 12 | palestine
# Processing Record 16 of Set 12 | ongandjera
# Processing Record 17 of Set 12 | bosaso
# Processing Record 18 of Set 12 | libourne
# Processing Record 19 of Set 12 | williston
# Processing Record 20 of Set 12 | goderich
# Processing Record 21 of Set 12 | richards bay
# Processing Record 22 of Set 12 | alice springs
# Processing Record 23 of Set 12 | cap malheureux
# Processing Record 24 of Set 12 | liaocheng
# Processing Record 25 of Set 12 | ngunguru
# Processing Record 26 of Set 12 | halifax
# Processing Record 27 of Set 12 | salta
# Processing Record 28 of Set 12 | ardalstangen
# Processing Record 29 of Set 12 | sobreira
# Processing Record 30 of Set 12 | pangnirtung
# Processing Record 31 of Set 12 | kedrovyy
# Processing Record 32 of Set 12 | waipawa
# Processing Record 33 of Set 12 | athabasca
# Processing Record 34 of Set 12 | koungou
# Processing Record 35 of Set 12 | vung tau
# Processing Record 36 of Set 12 | grindavik
# Processing Record 37 of Set 12 | bud
# Processing Record 38 of Set 12 | bocas del toro
# Processing Record 39 of Set 12 | guarapari
# Processing Record 40 of Set 12 | aswan
# Processing Record 41 of Set 12 | leshukonskoye
# Processing Record 42 of Set 12 | petropavlovskoye
# Processing Record 43 of Set 12 | chokwe
# Processing Record 44 of Set 12 | gizo
# Processing Record 45 of Set 12 | roma
# Processing Record 46 of Set 12 | kalengwa
# Processing Record 47 of Set 12 | japaratuba
# Processing Record 48 of Set 12 | progreso
# Processing Record 49 of Set 12 | araceli
# Processing Record 50 of Set 12 | kieta
# Processing Record 1 of Set 13 | nome
# Processing Record 2 of Set 13 | mashhad
# Processing Record 3 of Set 13 | palauig
# Processing Record 4 of Set 13 | tukrah
# Processing Record 5 of Set 13 | causapscal
# Processing Record 6 of Set 13 | cherskiy
# Processing Record 7 of Set 13 | bac lieu
# Processing Record 8 of Set 13 | peniche
# Processing Record 9 of Set 13 | camocim
# Processing Record 10 of Set 13 | shelburne
# Processing Record 11 of Set 13 | alta floresta
# Processing Record 12 of Set 13 | bani
# Processing Record 13 of Set 13 | carlyle
# Processing Record 14 of Set 13 | dryden
# Processing Record 15 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 16 of Set 13 | port keats
# Processing Record 17 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 18 of Set 13 | riachao das neves
# Processing Record 19 of Set 13 | chandur bazar
# Processing Record 20 of Set 13 | matara
# Processing Record 21 of Set 13 | kalmunai
# Processing Record 22 of Set 13 | san cristobal
# Processing Record 23 of Set 13 | sapele
# Processing Record 24 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 25 of Set 13 | ormara
# Processing Record 26 of Set 13 | waddan
# Processing Record 27 of Set 13 | sitka
# Processing Record 28 of Set 13 | leningradskiy
# Processing Record 29 of Set 13 | conceicao do araguaia
# Processing Record 30 of Set 13 | nanakuli
# Processing Record 31 of Set 13 | teguise
# Processing Record 32 of Set 13 | nuevo progreso
# Processing Record 33 of Set 13 | petauke
# Processing Record 34 of Set 13 | menongue
# Processing Record 35 of Set 13 | wonthaggi
# Processing Record 36 of Set 13 | pandaria
# Processing Record 37 of Set 13 | port-gentil
# Processing Record 38 of Set 13 | lazaro cardenas
# Processing Record 39 of Set 13 | tarakan
# Processing Record 40 of Set 13 | bouza
# Processing Record 41 of Set 13 | mocuba
# Processing Record 42 of Set 13 | shache
# Processing Record 43 of Set 13 | andrews
# Processing Record 44 of Set 13 | sumenep
# Processing Record 45 of Set 13 | alyangula
# Processing Record 46 of Set 13 | nemours
# Processing Record 47 of Set 13 | quatre cocos
# Processing Record 48 of Set 13 | juruti
# Processing Record 49 of Set 13 | havre-saint-pierre
# Processing Record 50 of Set 13 | denpasar
# Processing Record 1 of Set 14 | semikarakorsk
# Processing Record 2 of Set 14 | krivodol
# Processing Record 3 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 4 of Set 14 | beaverton
# Processing Record 5 of Set 14 | shimoda
# Processing Record 6 of Set 14 | kudymkar
# Processing Record 7 of Set 14 | coracora
# Processing Record 8 of Set 14 | mount isa
# Processing Record 9 of Set 14 | zabid
# Processing Record 10 of Set 14 | lata
# Processing Record 11 of Set 14 | rocha
# Processing Record 12 of Set 14 | bilma
# Processing Record 13 of Set 14 | vakhtan
# Processing Record 14 of Set 14 | rab
# City not found. Skipping...
# Processing Record 15 of Set 14 | bonfim
# Processing Record 16 of Set 14 | sorkjosen
# Processing Record 17 of Set 14 | oudtshoorn
# Processing Record 18 of Set 14 | kawhia
# Processing Record 19 of Set 14 | juneau
# Processing Record 20 of Set 14 | praya
# Processing Record 21 of Set 14 | hervey bay
# Processing Record 22 of Set 14 | oroville
# Processing Record 23 of Set 14 | verkhoyansk
# Processing Record 24 of Set 14 | orchard homes
# Processing Record 25 of Set 14 | kidal
# Processing Record 26 of Set 14 | roman
# Processing Record 27 of Set 14 | madang
# Processing Record 28 of Set 14 | yantal
# Processing Record 29 of Set 14 | lavrentiya
# Processing Record 30 of Set 14 | oksfjord
# Processing Record 31 of Set 14 | bandarban
# Processing Record 32 of Set 14 | turayf
# Processing Record 33 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 34 of Set 14 | santa rosa
# Processing Record 35 of Set 14 | caucaia
# Processing Record 36 of Set 14 | ferkessedougou
# Processing Record 37 of Set 14 | talusan
# Processing Record 38 of Set 14 | bida
# Processing Record 39 of Set 14 | maketu
# Processing Record 40 of Set 14 | saint-georges
# Processing Record 41 of Set 14 | pando
# Processing Record 42 of Set 14 | zheleznodorozhnyy
# Processing Record 43 of Set 14 | san jose
# Processing Record 44 of Set 14 | lodja
# Processing Record 45 of Set 14 | sijunjung
# Processing Record 46 of Set 14 | san ramon
# Processing Record 47 of Set 14 | arauca
# Processing Record 48 of Set 14 | kamenka
# Processing Record 49 of Set 14 | orlik
# Processing Record 50 of Set 14 | manzil jamil
# City not found. Skipping...
# Processing Record 1 of Set 15 | melilla
# Processing Record 2 of Set 15 | namatanai
# Processing Record 3 of Set 15 | haines junction
# Processing Record 4 of Set 15 | sawakin
# Processing Record 5 of Set 15 | champaign
# Processing Record 6 of Set 15 | linshui
# Processing Record 7 of Set 15 | kem
# Processing Record 8 of Set 15 | seguela
# Processing Record 9 of Set 15 | luzilandia
# Processing Record 10 of Set 15 | portoferraio
# Processing Record 11 of Set 15 | nayoro
# Processing Record 12 of Set 15 | mahon
# Processing Record 13 of Set 15 | ust-ordynskiy
# Processing Record 14 of Set 15 | verkhnevilyuysk
# Processing Record 15 of Set 15 | lerik
# Processing Record 16 of Set 15 | pauini
# Processing Record 17 of Set 15 | vaitape
# Processing Record 18 of Set 15 | dalvik
# Processing Record 19 of Set 15 | epe
# Processing Record 20 of Set 15 | falmouth
# Processing Record 21 of Set 15 | yarmouth
# Processing Record 22 of Set 15 | itoman
# Processing Record 23 of Set 15 | sola
# Processing Record 24 of Set 15 | gamba
# Processing Record 25 of Set 15 | sibu
# Processing Record 26 of Set 15 | kaduqli
# Processing Record 27 of Set 15 | safranbolu
# Processing Record 28 of Set 15 | axim
# Processing Record 29 of Set 15 | pasni
# Processing Record 30 of Set 15 | noyabrsk
# Processing Record 31 of Set 15 | balabac
# Processing Record 32 of Set 15 | smithers
# Processing Record 33 of Set 15 | povenets
# Processing Record 34 of Set 15 | kendari
# Processing Record 35 of Set 15 | sayat
# Processing Record 36 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 37 of Set 15 | ilo
# Processing Record 38 of Set 15 | massaguet
# Processing Record 39 of Set 15 | avera
# Processing Record 40 of Set 15 | port hedland
# Processing Record 41 of Set 15 | ketchikan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Busselton -33.6500  115.3333     62.64        77         100
# 1        Thompson  55.7435  -97.8558     33.96        93         100
# 2    Norman Wells  65.2820 -126.8329     14.77        87         100
# 3          Shetpe  44.1667   52.1167     51.93        67          34
# 4           Bluff -46.6000  168.3333     58.10        73           7
# ..            ...      ...       ...       ...       ...         ...
# 681           Ilo -17.6394  -71.3375     66.56        86          42
# 682     Massaguet  12.4755   15.4365     87.01        21         100
# 683         Avera  33.1940  -82.5271     44.11        58          16
# 684  Port Hedland -20.3167  118.5667     89.65        37           8
# 685     Ketchikan  55.3422 -131.6461     42.78        60          61
#
#      Wind Speed Country Current Discription
# 0         16.58      AU     overcast clouds
# 1         10.36      CA     overcast clouds
# 2         13.82      CA     overcast clouds
# 3          3.80      KZ    scattered clouds
# 4         23.85      NZ           clear sky
# ..          ...     ...                 ...
# 681        6.58      PE    scattered clouds
# 682        8.86      TD     overcast clouds
# 683        5.23      US          few clouds
# 684        4.61      AU           clear sky
# 685        4.79      US       broken clouds
#
# [686 rows x 9 columns]

# %%
new_column_order = ["City", "Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Discription"]
city_data_df[new_column_order].head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Busselton      AU -33.6500  115.3333     62.64        77         100
# 1      Thompson      CA  55.7435  -97.8558     33.96        93         100
# 2  Norman Wells      CA  65.2820 -126.8329     14.77        87         100
# 3        Shetpe      KZ  44.1667   52.1167     51.93        67          34
# 4         Bluff      NZ -46.6000  168.3333     58.10        73           7
# 5       Guanica      PR  17.9716  -66.9080     78.06        78          51
# 6         Vaini      TO -21.2000 -175.2000     84.36        74          20
# 7       Ushuaia      AR -54.8000  -68.3000     47.86        71          75
# 8   Port Alfred      ZA -33.5906   26.8910     62.19        96         100
# 9         Banyo      CM   6.7500   11.8167     67.48        84         100
#
#    Wind Speed Current Discription
# 0       16.58     overcast clouds
# 1       10.36     overcast clouds
# 2       13.82     overcast clouds
# 3        3.80    scattered clouds
# 4       23.85           clear sky
# 5        9.24       broken clouds
# 6        8.05          few clouds
# 7       16.11       broken clouds
# 8        7.00     overcast clouds
# 9        5.08     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
