# %%
# Import the random module.

# %%
import random

# %%
random.randint(-90, 90)

# %%
random.random()

# %%
random_number = random.randint(-90,89) + random.random()

# %%
random_number

# %%
x =1
latitudes =[]
random_lat = random.randint(-90,89)+random.random()
latitudes.append(random_lat)
x+=1

# %%
latitudes

# %%
random.randrange(-90, 90, step=1)

# %%
random.randrange(-90, 90, step=3)

# %%
random.uniform(-90, 90)

# %%
# Import the NumPy module.
import numpy as np

# %%
np.random.uniform(-90.000, 90.000)

# %%
# Import timeit.
import timeit

# %%
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 14.3 µs ± 438 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 1.73 ms ± 41.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# Create a set of random latitude and longitude combinations.
lats =np.random.uniform(low =90.00,high = 90.00,size =1500)
lngs = np.random.uniform(low= 180.00, high =180.00, size=1500)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x,y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates :
    print(coordinate[0],coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import the requests library.
import requests

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
#print(city_url)

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city.
# city_url = url + "&q=" +"Bston"
# city_weather = requests.get(city_url)
# city_weather

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.

city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}],"base":"stations","main":{"temp":59,"feels_like":56.07,"temp_min":54.09,"temp_max":63.28,"pressure":1016,"humidity":31},"visibility":10000,"wind":{"speed":9.22,"deg":280},"clouds":{"all":75},"dt":1649180128,"sys":{"type":2,"id":2013408,"country":"US","sunrise":1649153982,"sunset":1649200425},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 59,
#   'feels_like': 56.07,
#   'temp_min': 54.09,
#   'temp_max': 63.28,
#   'pressure': 1016,
#   'humidity': 31},
#  'visibility': 10000,
#  'wind': {'speed': 9.22, 'deg': 280},
#  'clouds': {'all': 75},
#  'dt': 1649180128,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1649153982,
#   'sunset': 1649200425},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code ==200:
    print(f"city weather found.")
else:
    print(f"city weather not found.")
# Out:
# city weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City weather not found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 58.93,
#   'feels_like': 55.98,
#   'temp_min': 54.09,
#   'temp_max': 63.14,
#   'pressure': 1016,
#   'humidity': 31},
#  'visibility': 10000,
#  'wind': {'speed': 9.22, 'deg': 280},
#  'clouds': {'all': 75},
#  'dt': 1649179916,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1649153982,
#   'sunset': 1649200425},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
boston_data['sys']
# Out:
# {'type': 2,
#  'id': 2013408,
#  'country': 'US',
#  'sunrise': 1649153982,
#  'sunset': 1649200425}

# %%
boston_data['sys']['country']
# Out:
# 'US'

# %%
boston_data['dt']
# Out:
# 1649179916

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data['dt']
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2022, 4, 5, 17, 31, 56)

# %%
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2022-04-05 17:31:56'

# %%
#Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 619

# %%
cities
# Out:
# ['attawapiskat',
#  'hilo',
#  'vila franca do campo',
#  'puerto ayora',
#  'tabialan',
#  'esperance',
#  'albany',
#  'jieshi',
#  'taolanaro',
#  'atuona',
#  'rikitea',
#  'mananara',
#  'bereda',
#  'saryshagan',
#  'bredasdorp',
#  'mayo',
#  'aljezur',
#  'malanje',
#  'bluff',
#  'punta arenas',
#  'nioro',
#  'cidreira',
#  'grand river south east',
#  'jiwani',
#  'rhyl',
#  'kapaa',
#  'mataura',
#  'kirakira',
#  'castro',
#  'darhan',
#  'thompson',
#  'monrovia',
#  'souillac',
#  'kawalu',
#  'butaritari',
#  'sinnamary',
#  'bethel',
#  'semnan',
#  'santiago del estero',
#  'cape town',
#  'ribeira grande',
#  'yellowknife',
#  'tual',
#  'belyy yar',
#  'sao filipe',
#  'zyryanovsk',
#  'eagle pass',
#  'jinxiang',
#  'griffith',
#  'busselton',
#  'hobart',
#  'haibowan',
#  'amderma',
#  'fort nelson',
#  'port alfred',
#  'belushya guba',
#  'barrow',
#  'ninghai',
#  'jamestown',
#  'port lincoln',
#  'okha',
#  'tautira',
#  'saint george',
#  'lavrentiya',
#  'fairbanks',
#  'saskylakh',
#  'illoqqortoormiut',
#  'constitucion',
#  'tuktoyaktuk',
#  'upernavik',
#  'kavieng',
#  'ginir',
#  'nur',
#  'quba',
#  'akdepe',
#  'adrar',
#  'barentsburg',
#  'faanui',
#  'new norfolk',
#  'ushuaia',
#  'arraial do cabo',
#  'katsuura',
#  'harrison',
#  'biak',
#  'dom pedrito',
#  'springbok',
#  'litoral del san juan',
#  'sentyabrskiy',
#  'shulan',
#  'clyde river',
#  'iskateley',
#  'paamiut',
#  'ileza',
#  'talara',
#  'vangaindrano',
#  'miri',
#  'port blair',
#  'aykhal',
#  'mount gambier',
#  'pevek',
#  'hovd',
#  'richards bay',
#  'labuhan',
#  'dicabisagan',
#  'khatanga',
#  'avarua',
#  'kavaratti',
#  'nantucket',
#  'mys shmidta',
#  'montclair',
#  'wanning',
#  'chokurdakh',
#  'lyuban',
#  'samusu',
#  'sabang',
#  'pokaran',
#  'port elizabeth',
#  'kaitangata',
#  'mana',
#  'kruisfontein',
#  'qaanaaq',
#  'mar del plata',
#  'sola',
#  'sidi ali',
#  'jasper',
#  'kankon',
#  'birjand',
#  'ous',
#  'coquimbo',
#  'sulangan',
#  'airai',
#  'oldmeldrum',
#  'ostrovnoy',
#  'east london',
#  'hamilton',
#  'lagoa',
#  'provideniya',
#  'tiksi',
#  'atasu',
#  'hermanus',
#  'palmer',
#  'tessalit',
#  'uruzgan',
#  'hithadhoo',
#  'santa lucia',
#  'bumba',
#  'atambua',
#  'paita',
#  'lata',
#  'murchison',
#  'abu samrah',
#  'ngukurr',
#  'husavik',
#  'kibara',
#  'pokhara',
#  'saint-philippe',
#  'cabo san lucas',
#  'cherkasskoye',
#  'porto belo',
#  'hasaki',
#  'carnarvon',
#  'san cristobal',
#  'college',
#  'luderitz',
#  'rawson',
#  'mayya',
#  'vostok',
#  'torbay',
#  'moshupa',
#  'pisco',
#  'altamira',
#  'ahipara',
#  'tadine',
#  'codrington',
#  'kefamenanu',
#  'porto walter',
#  'alakurtti',
#  'hohoe',
#  'redlands',
#  'jiexiu',
#  'anloga',
#  'cabedelo',
#  'sarangani',
#  'lindi',
#  'madimba',
#  'kahului',
#  'katrineholm',
#  'mahajanga',
#  'carutapera',
#  'babanusah',
#  'pitimbu',
#  'saldanha',
#  'chuy',
#  'lianzhou',
#  'totma',
#  'flinders',
#  'rawah',
#  'iqaluit',
#  'neuquen',
#  'bairnsdale',
#  'sioux lookout',
#  'vardo',
#  'mogadishu',
#  'komsomolskiy',
#  'saint joseph',
#  'matara',
#  'namatanai',
#  'muravlenko',
#  'iquitos',
#  'kiboga',
#  'kilimatinde',
#  'roma',
#  'kendari',
#  'howard springs',
#  'okato',
#  'haines junction',
#  'vaini',
#  'sangar',
#  'lebu',
#  'kalmunai',
#  'port augusta',
#  'san patricio',
#  'numata',
#  'pionerskiy',
#  'beringovskiy',
#  'severo-kurilsk',
#  'sakakah',
#  'luau',
#  'yumen',
#  'nueva loja',
#  'saint-augustin',
#  'dagda',
#  'paucartambo',
#  'berlevag',
#  'bozoum',
#  'grand gaube',
#  'lovozero',
#  'nikki',
#  'cherskiy',
#  'umm lajj',
#  'eydhafushi',
#  'road town',
#  'kupang',
#  'gornopravdinsk',
#  'westport',
#  'bulgan',
#  'alofi',
#  'gore',
#  'faya',
#  'vysokogornyy',
#  'milingimbi',
#  'salinas',
#  'umzimvubu',
#  'horodnye',
#  'hami',
#  'nabire',
#  'ust-kuyga',
#  'ayios vasilios',
#  'rio gallegos',
#  'kamphaeng phet',
#  'poya',
#  'skibbereen',
#  'tilichiki',
#  'leshan',
#  'usinsk',
#  'tatawin',
#  'tomatlan',
#  'serrinha',
#  'egvekinot',
#  'verkhnyaya toyma',
#  'segezha',
#  'isakly',
#  'pacific grove',
#  'talnakh',
#  'norman wells',
#  'laguna',
#  'klaksvik',
#  'ancud',
#  'mehamn',
#  'dikson',
#  'dunedin',
#  'dingle',
#  'hit',
#  'tasiilaq',
#  'georgetown',
#  'kamenka',
#  'cockburn town',
#  'ormos korthiou',
#  'ambanja',
#  'sitka',
#  'aquiraz',
#  'half moon bay',
#  'jumla',
#  'okakarara',
#  'port washington',
#  'muros',
#  'sault sainte marie',
#  'nanortalik',
#  'malpe',
#  'puerto carreno',
#  'stornoway',
#  'aleksandrov gay',
#  'hirara',
#  'lapusnicel',
#  'najran',
#  'coihaique',
#  'maragogi',
#  'naze',
#  'homer',
#  'spas',
#  'douentza',
#  'kaohsiung',
#  'touros',
#  'bantry',
#  'tuatapere',
#  'los llanos de aridane',
#  'broome',
#  'dwarka',
#  'nedumangad',
#  'almaznyy',
#  'verkhnyaya inta',
#  'kamenskoye',
#  'papetoai',
#  'saint-leu',
#  'zyryanka',
#  'zhanakorgan',
#  'axixa do tocantins',
#  'petropavlovsk-kamchatskiy',
#  'gat',
#  'bengkulu',
#  'lorengau',
#  'pochutla',
#  'sao felix do xingu',
#  'pierre',
#  'auki',
#  'chapais',
#  'vestmannaeyjar',
#  'dinsor',
#  'nikolskoye',
#  'nagato',
#  'bani',
#  'burica',
#  'burns lake',
#  'srivardhan',
#  'pinega',
#  'moranbah',
#  'milledgeville',
#  'alta floresta',
#  'palabuhanratu',
#  'chabahar',
#  'ayan',
#  'bafoulabe',
#  'ishigaki',
#  'mandalgovi',
#  'leshukonskoye',
#  'ruatoria',
#  'marrakesh',
#  'saleaula',
#  'ijaki',
#  'hambantota',
#  'lagos',
#  'akureyri',
#  'vao',
#  'isangel',
#  'samarai',
#  'louisbourg',
#  'mareeba',
#  'takoradi',
#  'san pedro',
#  'uyuni',
#  'amzya',
#  'kyra',
#  'leningradskiy',
#  'port macquarie',
#  'tyup',
#  'nizhneyansk',
#  'tsihombe',
#  'marsh harbour',
#  'erenhot',
#  'jiroft',
#  'necochea',
#  'lompoc',
#  'logan lake',
#  'izumo',
#  'eravur',
#  'zhuhai',
#  'baykit',
#  'lethem',
#  'grenaa',
#  'newtonmore',
#  'miraflores',
#  'ilulissat',
#  'matagami',
#  'victoria',
#  'port keats',
#  'lisakovsk',
#  'saint anthony',
#  'san andres',
#  'ponta do sol',
#  'marcona',
#  'artyom',
#  'orocue',
#  'shingu',
#  'salalah',
#  'manalongon',
#  'anzio',
#  'metro',
#  'kenai',
#  'puerto maldonado',
#  'jacqueville',
#  'abomsa',
#  'palu',
#  'dongsheng',
#  'trairi',
#  'uhlove',
#  'fortuna',
#  'saint-joseph',
#  'bambous virieux',
#  'namibe',
#  'timizart',
#  'strezhevoy',
#  'makakilo city',
#  'rio branco',
#  'sisimiut',
#  'margate',
#  'vaitupu',
#  'tunduma',
#  'yuzhno-yeniseyskiy',
#  'xining',
#  'ambilobe',
#  'alice springs',
#  'zemio',
#  'pangnirtung',
#  'la ronge',
#  'taltal',
#  'marsa matruh',
#  'port hardy',
#  'narsaq',
#  'dudinka',
#  'nahrin',
#  'atar',
#  'mhlambanyatsi',
#  'kodiak',
#  'tabiauea',
#  'bud',
#  'belomorsk',
#  'santa maria',
#  'spring hill',
#  'conde',
#  'saint-denis',
#  'labuan',
#  'kalomo',
#  'wulanhaote',
#  'molteno',
#  'waddan',
#  'berdigestyakh',
#  'longyearbyen',
#  'aswan',
#  'nizwa',
#  'tateyama',
#  'naples',
#  'agdam',
#  'adzhamka',
#  'la paz',
#  'honningsvag',
#  'korla',
#  'huarmey',
#  'hays',
#  'sorland',
#  'samalaeulu',
#  'oropesa',
#  'bokovskaya',
#  'mount kisco',
#  'vila velha',
#  'alyangula',
#  'nome',
#  'guerrero negro',
#  'lac du bonnet',
#  'walvis bay',
#  'sembakung',
#  'champerico',
#  'tagusao',
#  'frederico westphalen',
#  'huilong',
#  'acapulco',
#  'nurota',
#  'coahuayana',
#  'lubliniec',
#  'kununurra',
#  'asnaes',
#  'nuuk',
#  'tamandare',
#  'kiama',
#  'kismayo',
#  'lasa',
#  'bardiyah',
#  'bilibino',
#  'ibipeba',
#  'bathsheba',
#  'morondava',
#  'sambava',
#  'hofn',
#  'soavinandriana',
#  'harper',
#  'fergus falls',
#  'shimoda',
#  'hwange',
#  'minab',
#  'serik',
#  'perivolion',
#  'mizan teferi',
#  'aklavik',
#  'merauke',
#  'perth',
#  'magan',
#  'tasbuget',
#  'rimbey',
#  'olecko',
#  'zaozerne',
#  'velyka kisnytsya',
#  'buariki',
#  'benguela',
#  'fernley',
#  'wismar',
#  'hoi an',
#  'zhuanghe',
#  'balclutha',
#  'aranos',
#  'elat',
#  'charlottesville',
#  'japura',
#  'quime',
#  'north bend',
#  'luzhou',
#  'xai-xai',
#  'trelew',
#  'thinadhoo',
#  'nizhniy odes',
#  'channel-port aux basques',
#  'uige',
#  'talcahuano',
#  'tecoanapa',
#  'asyut',
#  'havre-saint-pierre',
#  'sao gabriel da cachoeira',
#  'marsabit',
#  'arlit',
#  'nata',
#  'green river',
#  'tura',
#  'jizan',
#  'te anau',
#  'mitsamiouli',
#  'verkh-chebula',
#  'bonavista',
#  'nhulunbuy',
#  'port hawkesbury',
#  'dalbandin',
#  'iquique',
#  'parksville',
#  'kashi',
#  'tumannyy',
#  'karratha',
#  'sept-iles',
#  'doncaster',
#  'las matas de farfan',
#  'comodoro rivadavia',
#  'malakal',
#  'cururupu',
#  'wilmington',
#  'naryan-mar',
#  'dogondoutchi',
#  'burgeo',
#  'shasta lake',
#  'inyonga',
#  'pak phanang',
#  'tiarei',
#  'elmira',
#  'yerbogachen',
#  'brewster',
#  'yeppoon',
#  'umm kaddadah',
#  'mwinilunga',
#  'wladyslawowo',
#  'khawhai',
#  'kaduna',
#  'krasnoselkup',
#  'tucupita',
#  'quatre cocos',
#  'sao jose da coroa grande',
#  'gubkinskiy',
#  'inirida',
#  'haradok',
#  'bangkal',
#  'san jeronimo',
#  'praya',
#  'igarka',
#  'bowen',
#  'southbridge',
#  'talaya',
#  'kamaishi',
#  'aksarka',
#  'hualmay',
#  'janesville',
#  'san rafael',
#  'powell',
#  'atka',
#  'praia da vitoria',
#  'northam',
#  'belaya gora',
#  'aksu',
#  'chiredzi',
#  'beloha',
#  'eureka',
#  'teberda',
#  'twentynine palms',
#  'tombouctou',
#  'pokrovsk',
#  'tulum']

# %%
import time
from datetime import datetime
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning of the logging ")
print("-------------------------")
# Create counters.
record_count =1
set_count = 1
# Out:
# Beginning of the logging
# -------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    #print(city_url)
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
                # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 1 | hilo
# Processing Record 3 of Set 1 | vila franca do campo
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | tabialan
# City not found. Skipping...
# Processing Record 6 of Set 1 | esperance
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | jieshi
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | mananara
# Processing Record 13 of Set 1 | bereda
# Processing Record 14 of Set 1 | saryshagan
# City not found. Skipping...
# Processing Record 15 of Set 1 | bredasdorp
# Processing Record 16 of Set 1 | mayo
# Processing Record 17 of Set 1 | aljezur
# Processing Record 18 of Set 1 | malanje
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | nioro
# Processing Record 22 of Set 1 | cidreira
# Processing Record 23 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 1 | jiwani
# Processing Record 25 of Set 1 | rhyl
# Processing Record 26 of Set 1 | kapaa
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | kirakira
# Processing Record 29 of Set 1 | castro
# Processing Record 30 of Set 1 | darhan
# Processing Record 31 of Set 1 | thompson
# Processing Record 32 of Set 1 | monrovia
# Processing Record 33 of Set 1 | souillac
# Processing Record 34 of Set 1 | kawalu
# Processing Record 35 of Set 1 | butaritari
# Processing Record 36 of Set 1 | sinnamary
# Processing Record 37 of Set 1 | bethel
# Processing Record 38 of Set 1 | semnan
# Processing Record 39 of Set 1 | santiago del estero
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | ribeira grande
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | tual
# Processing Record 44 of Set 1 | belyy yar
# Processing Record 45 of Set 1 | sao filipe
# Processing Record 46 of Set 1 | zyryanovsk
# Processing Record 47 of Set 1 | eagle pass
# Processing Record 48 of Set 1 | jinxiang
# Processing Record 49 of Set 1 | griffith
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | hobart
# Processing Record 2 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 3 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 2 | fort nelson
# Processing Record 5 of Set 2 | port alfred
# Processing Record 6 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 2 | barrow
# Processing Record 8 of Set 2 | ninghai
# Processing Record 9 of Set 2 | jamestown
# Processing Record 10 of Set 2 | port lincoln
# Processing Record 11 of Set 2 | okha
# Processing Record 12 of Set 2 | tautira
# Processing Record 13 of Set 2 | saint george
# Processing Record 14 of Set 2 | lavrentiya
# Processing Record 15 of Set 2 | fairbanks
# Processing Record 16 of Set 2 | saskylakh
# Processing Record 17 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 2 | constitucion
# Processing Record 19 of Set 2 | tuktoyaktuk
# Processing Record 20 of Set 2 | upernavik
# Processing Record 21 of Set 2 | kavieng
# Processing Record 22 of Set 2 | ginir
# Processing Record 23 of Set 2 | nur
# Processing Record 24 of Set 2 | quba
# Processing Record 25 of Set 2 | akdepe
# Processing Record 26 of Set 2 | adrar
# Processing Record 27 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 2 | faanui
# Processing Record 29 of Set 2 | new norfolk
# Processing Record 30 of Set 2 | ushuaia
# Processing Record 31 of Set 2 | arraial do cabo
# Processing Record 32 of Set 2 | katsuura
# Processing Record 33 of Set 2 | harrison
# Processing Record 34 of Set 2 | biak
# Processing Record 35 of Set 2 | dom pedrito
# Processing Record 36 of Set 2 | springbok
# Processing Record 37 of Set 2 | litoral del san juan
# City not found. Skipping...
# Processing Record 38 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 2 | shulan
# Processing Record 40 of Set 2 | clyde river
# Processing Record 41 of Set 2 | iskateley
# Processing Record 42 of Set 2 | paamiut
# Processing Record 43 of Set 2 | ileza
# Processing Record 44 of Set 2 | talara
# Processing Record 45 of Set 2 | vangaindrano
# Processing Record 46 of Set 2 | miri
# Processing Record 47 of Set 2 | port blair
# Processing Record 48 of Set 2 | aykhal
# Processing Record 49 of Set 2 | mount gambier
# Processing Record 50 of Set 2 | pevek
# Processing Record 1 of Set 3 | hovd
# Processing Record 2 of Set 3 | richards bay
# Processing Record 3 of Set 3 | labuhan
# Processing Record 4 of Set 3 | dicabisagan
# Processing Record 5 of Set 3 | khatanga
# Processing Record 6 of Set 3 | avarua
# Processing Record 7 of Set 3 | kavaratti
# Processing Record 8 of Set 3 | nantucket
# Processing Record 9 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 3 | montclair
# Processing Record 11 of Set 3 | wanning
# Processing Record 12 of Set 3 | chokurdakh
# Processing Record 13 of Set 3 | lyuban
# Processing Record 14 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 3 | sabang
# Processing Record 16 of Set 3 | pokaran
# Processing Record 17 of Set 3 | port elizabeth
# Processing Record 18 of Set 3 | kaitangata
# Processing Record 19 of Set 3 | mana
# Processing Record 20 of Set 3 | kruisfontein
# Processing Record 21 of Set 3 | qaanaaq
# Processing Record 22 of Set 3 | mar del plata
# Processing Record 23 of Set 3 | sola
# Processing Record 24 of Set 3 | sidi ali
# Processing Record 25 of Set 3 | jasper
# Processing Record 26 of Set 3 | kankon
# Processing Record 27 of Set 3 | birjand
# Processing Record 28 of Set 3 | ous
# Processing Record 29 of Set 3 | coquimbo
# Processing Record 30 of Set 3 | sulangan
# Processing Record 31 of Set 3 | airai
# Processing Record 32 of Set 3 | oldmeldrum
# Processing Record 33 of Set 3 | ostrovnoy
# Processing Record 34 of Set 3 | east london
# Processing Record 35 of Set 3 | hamilton
# Processing Record 36 of Set 3 | lagoa
# Processing Record 37 of Set 3 | provideniya
# Processing Record 38 of Set 3 | tiksi
# Processing Record 39 of Set 3 | atasu
# Processing Record 40 of Set 3 | hermanus
# Processing Record 41 of Set 3 | palmer
# Processing Record 42 of Set 3 | tessalit
# Processing Record 43 of Set 3 | uruzgan
# Processing Record 44 of Set 3 | hithadhoo
# Processing Record 45 of Set 3 | santa lucia
# Processing Record 46 of Set 3 | bumba
# Processing Record 47 of Set 3 | atambua
# Processing Record 48 of Set 3 | paita
# Processing Record 49 of Set 3 | lata
# Processing Record 50 of Set 3 | murchison
# Processing Record 1 of Set 4 | abu samrah
# Processing Record 2 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 3 of Set 4 | husavik
# Processing Record 4 of Set 4 | kibara
# Processing Record 5 of Set 4 | pokhara
# Processing Record 6 of Set 4 | saint-philippe
# Processing Record 7 of Set 4 | cabo san lucas
# Processing Record 8 of Set 4 | cherkasskoye
# Processing Record 9 of Set 4 | porto belo
# Processing Record 10 of Set 4 | hasaki
# Processing Record 11 of Set 4 | carnarvon
# Processing Record 12 of Set 4 | san cristobal
# Processing Record 13 of Set 4 | college
# Processing Record 14 of Set 4 | luderitz
# Processing Record 15 of Set 4 | rawson
# Processing Record 16 of Set 4 | mayya
# Processing Record 17 of Set 4 | vostok
# Processing Record 18 of Set 4 | torbay
# Processing Record 19 of Set 4 | moshupa
# Processing Record 20 of Set 4 | pisco
# Processing Record 21 of Set 4 | altamira
# Processing Record 22 of Set 4 | ahipara
# Processing Record 23 of Set 4 | tadine
# Processing Record 24 of Set 4 | codrington
# Processing Record 25 of Set 4 | kefamenanu
# Processing Record 26 of Set 4 | porto walter
# Processing Record 27 of Set 4 | alakurtti
# Processing Record 28 of Set 4 | hohoe
# Processing Record 29 of Set 4 | redlands
# Processing Record 30 of Set 4 | jiexiu
# Processing Record 31 of Set 4 | anloga
# Processing Record 32 of Set 4 | cabedelo
# Processing Record 33 of Set 4 | sarangani
# Processing Record 34 of Set 4 | lindi
# Processing Record 35 of Set 4 | madimba
# Processing Record 36 of Set 4 | kahului
# Processing Record 37 of Set 4 | katrineholm
# Processing Record 38 of Set 4 | mahajanga
# Processing Record 39 of Set 4 | carutapera
# Processing Record 40 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 41 of Set 4 | pitimbu
# Processing Record 42 of Set 4 | saldanha
# Processing Record 43 of Set 4 | chuy
# Processing Record 44 of Set 4 | lianzhou
# Processing Record 45 of Set 4 | totma
# Processing Record 46 of Set 4 | flinders
# Processing Record 47 of Set 4 | rawah
# Processing Record 48 of Set 4 | iqaluit
# Processing Record 49 of Set 4 | neuquen
# Processing Record 50 of Set 4 | bairnsdale
# Processing Record 1 of Set 5 | sioux lookout
# Processing Record 2 of Set 5 | vardo
# Processing Record 3 of Set 5 | mogadishu
# Processing Record 4 of Set 5 | komsomolskiy
# Processing Record 5 of Set 5 | saint joseph
# Processing Record 6 of Set 5 | matara
# Processing Record 7 of Set 5 | namatanai
# Processing Record 8 of Set 5 | muravlenko
# Processing Record 9 of Set 5 | iquitos
# Processing Record 10 of Set 5 | kiboga
# Processing Record 11 of Set 5 | kilimatinde
# Processing Record 12 of Set 5 | roma
# Processing Record 13 of Set 5 | kendari
# Processing Record 14 of Set 5 | howard springs
# Processing Record 15 of Set 5 | okato
# Processing Record 16 of Set 5 | haines junction
# Processing Record 17 of Set 5 | vaini
# Processing Record 18 of Set 5 | sangar
# Processing Record 19 of Set 5 | lebu
# Processing Record 20 of Set 5 | kalmunai
# Processing Record 21 of Set 5 | port augusta
# Processing Record 22 of Set 5 | san patricio
# Processing Record 23 of Set 5 | numata
# Processing Record 24 of Set 5 | pionerskiy
# Processing Record 25 of Set 5 | beringovskiy
# Processing Record 26 of Set 5 | severo-kurilsk
# Processing Record 27 of Set 5 | sakakah
# Processing Record 28 of Set 5 | luau
# Processing Record 29 of Set 5 | yumen
# Processing Record 30 of Set 5 | nueva loja
# Processing Record 31 of Set 5 | saint-augustin
# Processing Record 32 of Set 5 | dagda
# Processing Record 33 of Set 5 | paucartambo
# City not found. Skipping...
# Processing Record 34 of Set 5 | berlevag
# Processing Record 35 of Set 5 | bozoum
# Processing Record 36 of Set 5 | grand gaube
# Processing Record 37 of Set 5 | lovozero
# Processing Record 38 of Set 5 | nikki
# Processing Record 39 of Set 5 | cherskiy
# Processing Record 40 of Set 5 | umm lajj
# Processing Record 41 of Set 5 | eydhafushi
# Processing Record 42 of Set 5 | road town
# Processing Record 43 of Set 5 | kupang
# Processing Record 44 of Set 5 | gornopravdinsk
# Processing Record 45 of Set 5 | westport
# Processing Record 46 of Set 5 | bulgan
# Processing Record 47 of Set 5 | alofi
# Processing Record 48 of Set 5 | gore
# Processing Record 49 of Set 5 | faya
# Processing Record 50 of Set 5 | vysokogornyy
# Processing Record 1 of Set 6 | milingimbi
# City not found. Skipping...
# Processing Record 2 of Set 6 | salinas
# Processing Record 3 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 6 | horodnye
# Processing Record 5 of Set 6 | hami
# Processing Record 6 of Set 6 | nabire
# Processing Record 7 of Set 6 | ust-kuyga
# Processing Record 8 of Set 6 | ayios vasilios
# Processing Record 9 of Set 6 | rio gallegos
# Processing Record 10 of Set 6 | kamphaeng phet
# Processing Record 11 of Set 6 | poya
# Processing Record 12 of Set 6 | skibbereen
# Processing Record 13 of Set 6 | tilichiki
# Processing Record 14 of Set 6 | leshan
# Processing Record 15 of Set 6 | usinsk
# Processing Record 16 of Set 6 | tatawin
# Processing Record 17 of Set 6 | tomatlan
# Processing Record 18 of Set 6 | serrinha
# Processing Record 19 of Set 6 | egvekinot
# Processing Record 20 of Set 6 | verkhnyaya toyma
# Processing Record 21 of Set 6 | segezha
# Processing Record 22 of Set 6 | isakly
# Processing Record 23 of Set 6 | pacific grove
# Processing Record 24 of Set 6 | talnakh
# Processing Record 25 of Set 6 | norman wells
# Processing Record 26 of Set 6 | laguna
# Processing Record 27 of Set 6 | klaksvik
# Processing Record 28 of Set 6 | ancud
# Processing Record 29 of Set 6 | mehamn
# Processing Record 30 of Set 6 | dikson
# Processing Record 31 of Set 6 | dunedin
# Processing Record 32 of Set 6 | dingle
# Processing Record 33 of Set 6 | hit
# Processing Record 34 of Set 6 | tasiilaq
# Processing Record 35 of Set 6 | georgetown
# Processing Record 36 of Set 6 | kamenka
# Processing Record 37 of Set 6 | cockburn town
# Processing Record 38 of Set 6 | ormos korthiou
# City not found. Skipping...
# Processing Record 39 of Set 6 | ambanja
# Processing Record 40 of Set 6 | sitka
# Processing Record 41 of Set 6 | aquiraz
# Processing Record 42 of Set 6 | half moon bay
# Processing Record 43 of Set 6 | jumla
# Processing Record 44 of Set 6 | okakarara
# Processing Record 45 of Set 6 | port washington
# Processing Record 46 of Set 6 | muros
# Processing Record 47 of Set 6 | sault sainte marie
# Processing Record 48 of Set 6 | nanortalik
# Processing Record 49 of Set 6 | malpe
# Processing Record 50 of Set 6 | puerto carreno
# Processing Record 1 of Set 7 | stornoway
# Processing Record 2 of Set 7 | aleksandrov gay
# Processing Record 3 of Set 7 | hirara
# Processing Record 4 of Set 7 | lapusnicel
# Processing Record 5 of Set 7 | najran
# Processing Record 6 of Set 7 | coihaique
# Processing Record 7 of Set 7 | maragogi
# Processing Record 8 of Set 7 | naze
# Processing Record 9 of Set 7 | homer
# Processing Record 10 of Set 7 | spas
# Processing Record 11 of Set 7 | douentza
# Processing Record 12 of Set 7 | kaohsiung
# Processing Record 13 of Set 7 | touros
# Processing Record 14 of Set 7 | bantry
# Processing Record 15 of Set 7 | tuatapere
# Processing Record 16 of Set 7 | los llanos de aridane
# Processing Record 17 of Set 7 | broome
# Processing Record 18 of Set 7 | dwarka
# Processing Record 19 of Set 7 | nedumangad
# Processing Record 20 of Set 7 | almaznyy
# Processing Record 21 of Set 7 | verkhnyaya inta
# Processing Record 22 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 7 | papetoai
# Processing Record 24 of Set 7 | saint-leu
# Processing Record 25 of Set 7 | zyryanka
# Processing Record 26 of Set 7 | zhanakorgan
# Processing Record 27 of Set 7 | axixa do tocantins
# City not found. Skipping...
# Processing Record 28 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 7 | gat
# Processing Record 30 of Set 7 | bengkulu
# Processing Record 31 of Set 7 | lorengau
# Processing Record 32 of Set 7 | pochutla
# Processing Record 33 of Set 7 | sao felix do xingu
# Processing Record 34 of Set 7 | pierre
# Processing Record 35 of Set 7 | auki
# Processing Record 36 of Set 7 | chapais
# Processing Record 37 of Set 7 | vestmannaeyjar
# Processing Record 38 of Set 7 | dinsor
# City not found. Skipping...
# Processing Record 39 of Set 7 | nikolskoye
# Processing Record 40 of Set 7 | nagato
# Processing Record 41 of Set 7 | bani
# Processing Record 42 of Set 7 | burica
# City not found. Skipping...
# Processing Record 43 of Set 7 | burns lake
# Processing Record 44 of Set 7 | srivardhan
# Processing Record 45 of Set 7 | pinega
# Processing Record 46 of Set 7 | moranbah
# Processing Record 47 of Set 7 | milledgeville
# Processing Record 48 of Set 7 | alta floresta
# Processing Record 49 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 7 | chabahar
# Processing Record 1 of Set 8 | ayan
# Processing Record 2 of Set 8 | bafoulabe
# Processing Record 3 of Set 8 | ishigaki
# Processing Record 4 of Set 8 | mandalgovi
# Processing Record 5 of Set 8 | leshukonskoye
# Processing Record 6 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 7 of Set 8 | marrakesh
# Processing Record 8 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 10 of Set 8 | hambantota
# Processing Record 11 of Set 8 | lagos
# Processing Record 12 of Set 8 | akureyri
# Processing Record 13 of Set 8 | vao
# Processing Record 14 of Set 8 | isangel
# Processing Record 15 of Set 8 | samarai
# Processing Record 16 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 17 of Set 8 | mareeba
# Processing Record 18 of Set 8 | takoradi
# Processing Record 19 of Set 8 | san pedro
# Processing Record 20 of Set 8 | uyuni
# Processing Record 21 of Set 8 | amzya
# Processing Record 22 of Set 8 | kyra
# Processing Record 23 of Set 8 | leningradskiy
# Processing Record 24 of Set 8 | port macquarie
# Processing Record 25 of Set 8 | tyup
# Processing Record 26 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 8 | marsh harbour
# Processing Record 29 of Set 8 | erenhot
# Processing Record 30 of Set 8 | jiroft
# City not found. Skipping...
# Processing Record 31 of Set 8 | necochea
# Processing Record 32 of Set 8 | lompoc
# Processing Record 33 of Set 8 | logan lake
# Processing Record 34 of Set 8 | izumo
# Processing Record 35 of Set 8 | eravur
# Processing Record 36 of Set 8 | zhuhai
# Processing Record 37 of Set 8 | baykit
# Processing Record 38 of Set 8 | lethem
# Processing Record 39 of Set 8 | grenaa
# Processing Record 40 of Set 8 | newtonmore
# Processing Record 41 of Set 8 | miraflores
# Processing Record 42 of Set 8 | ilulissat
# Processing Record 43 of Set 8 | matagami
# Processing Record 44 of Set 8 | victoria
# Processing Record 45 of Set 8 | port keats
# Processing Record 46 of Set 8 | lisakovsk
# Processing Record 47 of Set 8 | saint anthony
# Processing Record 48 of Set 8 | san andres
# Processing Record 49 of Set 8 | ponta do sol
# Processing Record 50 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 9 | artyom
# Processing Record 2 of Set 9 | orocue
# Processing Record 3 of Set 9 | shingu
# Processing Record 4 of Set 9 | salalah
# Processing Record 5 of Set 9 | manalongon
# Processing Record 6 of Set 9 | anzio
# Processing Record 7 of Set 9 | metro
# Processing Record 8 of Set 9 | kenai
# Processing Record 9 of Set 9 | puerto maldonado
# Processing Record 10 of Set 9 | jacqueville
# Processing Record 11 of Set 9 | abomsa
# Processing Record 12 of Set 9 | palu
# Processing Record 13 of Set 9 | dongsheng
# Processing Record 14 of Set 9 | trairi
# Processing Record 15 of Set 9 | uhlove
# Processing Record 16 of Set 9 | fortuna
# Processing Record 17 of Set 9 | saint-joseph
# Processing Record 18 of Set 9 | bambous virieux
# Processing Record 19 of Set 9 | namibe
# Processing Record 20 of Set 9 | timizart
# Processing Record 21 of Set 9 | strezhevoy
# Processing Record 22 of Set 9 | makakilo city
# Processing Record 23 of Set 9 | rio branco
# Processing Record 24 of Set 9 | sisimiut
# Processing Record 25 of Set 9 | margate
# Processing Record 26 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 9 | tunduma
# Processing Record 28 of Set 9 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 29 of Set 9 | xining
# Processing Record 30 of Set 9 | ambilobe
# Processing Record 31 of Set 9 | alice springs
# Processing Record 32 of Set 9 | zemio
# Processing Record 33 of Set 9 | pangnirtung
# Processing Record 34 of Set 9 | la ronge
# Processing Record 35 of Set 9 | taltal
# Processing Record 36 of Set 9 | marsa matruh
# Processing Record 37 of Set 9 | port hardy
# Processing Record 38 of Set 9 | narsaq
# Processing Record 39 of Set 9 | dudinka
# Processing Record 40 of Set 9 | nahrin
# Processing Record 41 of Set 9 | atar
# Processing Record 42 of Set 9 | mhlambanyatsi
# Processing Record 43 of Set 9 | kodiak
# Processing Record 44 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 45 of Set 9 | bud
# Processing Record 46 of Set 9 | belomorsk
# Processing Record 47 of Set 9 | santa maria
# Processing Record 48 of Set 9 | spring hill
# Processing Record 49 of Set 9 | conde
# Processing Record 50 of Set 9 | saint-denis
# Processing Record 1 of Set 10 | labuan
# Processing Record 2 of Set 10 | kalomo
# City not found. Skipping...
# Processing Record 3 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 4 of Set 10 | molteno
# Processing Record 5 of Set 10 | waddan
# Processing Record 6 of Set 10 | berdigestyakh
# Processing Record 7 of Set 10 | longyearbyen
# Processing Record 8 of Set 10 | aswan
# Processing Record 9 of Set 10 | nizwa
# Processing Record 10 of Set 10 | tateyama
# Processing Record 11 of Set 10 | naples
# Processing Record 12 of Set 10 | agdam
# Processing Record 13 of Set 10 | adzhamka
# Processing Record 14 of Set 10 | la paz
# Processing Record 15 of Set 10 | honningsvag
# Processing Record 16 of Set 10 | korla
# Processing Record 17 of Set 10 | huarmey
# Processing Record 18 of Set 10 | hays
# Processing Record 19 of Set 10 | sorland
# Processing Record 20 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 21 of Set 10 | oropesa
# Processing Record 22 of Set 10 | bokovskaya
# Processing Record 23 of Set 10 | mount kisco
# Processing Record 24 of Set 10 | vila velha
# Processing Record 25 of Set 10 | alyangula
# Processing Record 26 of Set 10 | nome
# Processing Record 27 of Set 10 | guerrero negro
# Processing Record 28 of Set 10 | lac du bonnet
# Processing Record 29 of Set 10 | walvis bay
# Processing Record 30 of Set 10 | sembakung
# Processing Record 31 of Set 10 | champerico
# Processing Record 32 of Set 10 | tagusao
# Processing Record 33 of Set 10 | frederico westphalen
# Processing Record 34 of Set 10 | huilong
# Processing Record 35 of Set 10 | acapulco
# Processing Record 36 of Set 10 | nurota
# Processing Record 37 of Set 10 | coahuayana
# Processing Record 38 of Set 10 | lubliniec
# Processing Record 39 of Set 10 | kununurra
# Processing Record 40 of Set 10 | asnaes
# Processing Record 41 of Set 10 | nuuk
# Processing Record 42 of Set 10 | tamandare
# Processing Record 43 of Set 10 | kiama
# Processing Record 44 of Set 10 | kismayo
# Processing Record 45 of Set 10 | lasa
# Processing Record 46 of Set 10 | bardiyah
# Processing Record 47 of Set 10 | bilibino
# Processing Record 48 of Set 10 | ibipeba
# Processing Record 49 of Set 10 | bathsheba
# Processing Record 50 of Set 10 | morondava
# Processing Record 1 of Set 11 | sambava
# Processing Record 2 of Set 11 | hofn
# Processing Record 3 of Set 11 | soavinandriana
# Processing Record 4 of Set 11 | harper
# Processing Record 5 of Set 11 | fergus falls
# Processing Record 6 of Set 11 | shimoda
# Processing Record 7 of Set 11 | hwange
# Processing Record 8 of Set 11 | minab
# Processing Record 9 of Set 11 | serik
# Processing Record 10 of Set 11 | perivolion
# Processing Record 11 of Set 11 | mizan teferi
# Processing Record 12 of Set 11 | aklavik
# Processing Record 13 of Set 11 | merauke
# Processing Record 14 of Set 11 | perth
# Processing Record 15 of Set 11 | magan
# Processing Record 16 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 17 of Set 11 | rimbey
# Processing Record 18 of Set 11 | olecko
# Processing Record 19 of Set 11 | zaozerne
# Processing Record 20 of Set 11 | velyka kisnytsya
# City not found. Skipping...
# Processing Record 21 of Set 11 | buariki
# City not found. Skipping...
# Processing Record 22 of Set 11 | benguela
# Processing Record 23 of Set 11 | fernley
# Processing Record 24 of Set 11 | wismar
# Processing Record 25 of Set 11 | hoi an
# Processing Record 26 of Set 11 | zhuanghe
# Processing Record 27 of Set 11 | balclutha
# Processing Record 28 of Set 11 | aranos
# Processing Record 29 of Set 11 | elat
# Processing Record 30 of Set 11 | charlottesville
# Processing Record 31 of Set 11 | japura
# Processing Record 32 of Set 11 | quime
# Processing Record 33 of Set 11 | north bend
# Processing Record 34 of Set 11 | luzhou
# Processing Record 35 of Set 11 | xai-xai
# Processing Record 36 of Set 11 | trelew
# Processing Record 37 of Set 11 | thinadhoo
# Processing Record 38 of Set 11 | nizhniy odes
# Processing Record 39 of Set 11 | channel-port aux basques
# Processing Record 40 of Set 11 | uige
# Processing Record 41 of Set 11 | talcahuano
# Processing Record 42 of Set 11 | tecoanapa
# Processing Record 43 of Set 11 | asyut
# Processing Record 44 of Set 11 | havre-saint-pierre
# Processing Record 45 of Set 11 | sao gabriel da cachoeira
# Processing Record 46 of Set 11 | marsabit
# Processing Record 47 of Set 11 | arlit
# Processing Record 48 of Set 11 | nata
# Processing Record 49 of Set 11 | green river
# Processing Record 50 of Set 11 | tura
# Processing Record 1 of Set 12 | jizan
# Processing Record 2 of Set 12 | te anau
# Processing Record 3 of Set 12 | mitsamiouli
# Processing Record 4 of Set 12 | verkh-chebula
# Processing Record 5 of Set 12 | bonavista
# Processing Record 6 of Set 12 | nhulunbuy
# Processing Record 7 of Set 12 | port hawkesbury
# Processing Record 8 of Set 12 | dalbandin
# Processing Record 9 of Set 12 | iquique
# Processing Record 10 of Set 12 | parksville
# Processing Record 11 of Set 12 | kashi
# Processing Record 12 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 12 | karratha
# Processing Record 14 of Set 12 | sept-iles
# Processing Record 15 of Set 12 | doncaster
# Processing Record 16 of Set 12 | las matas de farfan
# Processing Record 17 of Set 12 | comodoro rivadavia
# Processing Record 18 of Set 12 | malakal
# Processing Record 19 of Set 12 | cururupu
# Processing Record 20 of Set 12 | wilmington
# Processing Record 21 of Set 12 | naryan-mar
# Processing Record 22 of Set 12 | dogondoutchi
# Processing Record 23 of Set 12 | burgeo
# Processing Record 24 of Set 12 | shasta lake
# Processing Record 25 of Set 12 | inyonga
# Processing Record 26 of Set 12 | pak phanang
# Processing Record 27 of Set 12 | tiarei
# Processing Record 28 of Set 12 | elmira
# Processing Record 29 of Set 12 | yerbogachen
# Processing Record 30 of Set 12 | brewster
# Processing Record 31 of Set 12 | yeppoon
# Processing Record 32 of Set 12 | umm kaddadah
# Processing Record 33 of Set 12 | mwinilunga
# Processing Record 34 of Set 12 | wladyslawowo
# Processing Record 35 of Set 12 | khawhai
# Processing Record 36 of Set 12 | kaduna
# Processing Record 37 of Set 12 | krasnoselkup
# Processing Record 38 of Set 12 | tucupita
# Processing Record 39 of Set 12 | quatre cocos
# Processing Record 40 of Set 12 | sao jose da coroa grande
# Processing Record 41 of Set 12 | gubkinskiy
# Processing Record 42 of Set 12 | inirida
# Processing Record 43 of Set 12 | haradok
# Processing Record 44 of Set 12 | bangkal
# Processing Record 45 of Set 12 | san jeronimo
# Processing Record 46 of Set 12 | praya
# Processing Record 47 of Set 12 | igarka
# Processing Record 48 of Set 12 | bowen
# Processing Record 49 of Set 12 | southbridge
# Processing Record 50 of Set 12 | talaya
# Processing Record 1 of Set 13 | kamaishi
# Processing Record 2 of Set 13 | aksarka
# Processing Record 3 of Set 13 | hualmay
# Processing Record 4 of Set 13 | janesville
# Processing Record 5 of Set 13 | san rafael
# Processing Record 6 of Set 13 | powell
# Processing Record 7 of Set 13 | atka
# City not found. Skipping...
# Processing Record 8 of Set 13 | praia da vitoria
# Processing Record 9 of Set 13 | northam
# Processing Record 10 of Set 13 | belaya gora
# Processing Record 11 of Set 13 | aksu
# Processing Record 12 of Set 13 | chiredzi
# Processing Record 13 of Set 13 | beloha
# Processing Record 14 of Set 13 | eureka
# Processing Record 15 of Set 13 | teberda
# Processing Record 16 of Set 13 | twentynine palms
# Processing Record 17 of Set 13 | tombouctou
# Processing Record 18 of Set 13 | pokrovsk
# Processing Record 19 of Set 13 | tulum
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                  Hilo  19.7297 -155.0900     72.10        90         100
# 1  Vila Franca Do Campo  37.7167  -25.4333     61.21        58          93
# 2          Puerto Ayora  -0.7393  -90.3518     84.16        86          66
# 3             Esperance -33.8667  121.9000     60.64        72          94
# 4                Albany  42.6001  -73.9662     59.40        41          59
# 5                Jieshi  22.8134  115.8257     70.95        72          46
# 6                Atuona  -9.8000 -139.0333     79.00        75          52
# 7               Rikitea -23.1203 -134.9692     78.85        69          13
# 8              Mananara -16.1667   49.7667     75.90        95          90
# 9                Bereda  43.2686   -7.5406     48.58        64           0
#
#    Wind Speed Country                 Date
# 0        1.01      US  2022-04-05 18:21:30
# 1        2.68      PT  2022-04-05 18:26:15
# 2        7.00      EC  2022-04-05 18:26:16
# 3        6.73      AU  2022-04-05 18:26:16
# 4        1.99      US  2022-04-05 18:26:47
# 5        6.49      CN  2022-04-05 18:26:48
# 6       23.87      PF  2022-04-05 18:26:48
# 7       19.91      PF  2022-04-05 18:26:48
# 8        4.09      MG  2022-04-05 18:26:49
# 9        6.60      ES  2022-04-05 18:26:49

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
new_column_order = ["City", "Country", "Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed"]
city_data_df[new_column_order].head(10)
# Out:
#                    City Country                 Date      Lat       Lng  \
# 0                  Hilo      US  2022-04-05 18:21:30  19.7297 -155.0900
# 1  Vila Franca Do Campo      PT  2022-04-05 18:26:15  37.7167  -25.4333
# 2          Puerto Ayora      EC  2022-04-05 18:26:16  -0.7393  -90.3518
# 3             Esperance      AU  2022-04-05 18:26:16 -33.8667  121.9000
# 4                Albany      US  2022-04-05 18:26:47  42.6001  -73.9662
# 5                Jieshi      CN  2022-04-05 18:26:48  22.8134  115.8257
# 6                Atuona      PF  2022-04-05 18:26:48  -9.8000 -139.0333
# 7               Rikitea      PF  2022-04-05 18:26:48 -23.1203 -134.9692
# 8              Mananara      MG  2022-04-05 18:26:49 -16.1667   49.7667
# 9                Bereda      ES  2022-04-05 18:26:49  43.2686   -7.5406
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     72.10        90         100        1.01
# 1     61.21        58          93        2.68
# 2     84.16        86          66        7.00
# 3     60.64        72          94        6.73
# 4     59.40        41          59        1.99
# 5     70.95        72          46        6.49
# 6     79.00        75          52       23.87
# 7     78.85        69          13       19.91
# 8     75.90        95          90        4.09
# 9     48.58        64           0        6.60

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today
# Out:
# 1649190439.1076207

# %%
# Import time module
import time
#Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
           max_temps,
           edgecolor ='black', linewidths =1, marker ='o',
           alpha=0.8, label = "Cities")
